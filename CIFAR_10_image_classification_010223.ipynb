# %% [markdown]
# # **CIFAR-10 image classification**

# %% [markdown]
# ### Load, pre-process and explore data

# %%
# Import libraries
import json 
from pprint import pprint
import torch
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import Counter

# %%
# Define transformation
transform_train_0 = transforms.Compose([
    transforms.ToTensor(),
]) # basic trasformation

transform_train_1 = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.49139968,0.48215841,0.44653091), (0.24703223,0.24348513,0.26158784)),
]) # transformation with normalization

transform_train_2 = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.49139968,0.48215841,0.44653091), (0.24703223,0.24348513,0.26158784)),
    transforms.RandomHorizontalFlip(0.3),
    transforms.RandomVerticalFlip(0.3),
    transforms.ColorJitter(),
]) # transformation with normalization & augmentation

transform_train_3 = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(0.3),
    transforms.RandomVerticalFlip(0.3),
    transforms.ColorJitter(),
]) # transformation with augmentation

transform_val_0 = transforms.Compose([transforms.ToTensor(),
                                     ])

transform_val_1 = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.49139968,0.48215841,0.44653091), (0.24703223,0.24348513,0.26158784)),
                                     ])
# Define batch size
batch_size=32

# Load data
trainset_0 = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train_0)
train_dataloader_0 = torch.utils.data.DataLoader(trainset_0, batch_size=batch_size , shuffle=True)

trainset_1 = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train_1)
train_dataloader_1 = torch.utils.data.DataLoader(trainset_1, batch_size=batch_size , shuffle=True)

trainset_2 = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train_2)
train_dataloader_2 = torch.utils.data.DataLoader(trainset_2, batch_size=batch_size , shuffle=True)

trainset_3 = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train_3)
train_dataloader_3 = torch.utils.data.DataLoader(trainset_3, batch_size=batch_size , shuffle=True)

valset_0 = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_val_0)
val_dataloader_0 = torch.utils.data.DataLoader(valset_0, batch_size= batch_size, shuffle=False)

valset_1 = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_val_1)
val_dataloader_1 = torch.utils.data.DataLoader(valset_1, batch_size= batch_size, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Check shape
print("train data shape:", trainset_0.data.shape)
print("test data shape:",valset_0.data.shape)
# Out:
# train data shape: (50000, 32, 32, 3)
# test data shape: (10000, 32, 32, 3)

# %%
# Label dictionary
label_dict = {0:"airplane",1:"automobile",2:"bird",3:"cat",4:"deer",5:"dog",6:"frog",7:"horse",8:"ship",9:"truck"}

# %%
# Label distribution
c_train = Counter(trainset_0.targets)
c_val = Counter(valset_0.targets)
X = [label_dict[k] for k in c_train.keys()]
X_axis = np.arange(len(X))
plt.figure(figsize=(10,4))
plt.bar(X_axis - 0.2, c_train.values(), 0.4, label = 'train data')
plt.bar(X_axis + 0.2, c_val.values(), 0.4, label = 'validation data')
plt.xticks(X_axis, X)
plt.xlabel("Label")
plt.ylabel("Number of labels")
plt.legend()
plt.show()

# %%
# Plot random images
image_idx = [0,1001,3550,12310,31674,42763,2,3,4,5,6,7]
fig = plt.figure(figsize=(18,6))
fig.subplots_adjust(hspace=0.1, wspace=0.5)

for i in range(len(image_idx)):
  img_index = image_idx[i]
  # Load image at index img_index
  rgb_img = trainset_0.data[img_index]
  rgb_img = rgb_img.astype('float32')    
  rgb_img/= 255.0

  # Plot
  ax = fig.add_subplot(2, 6, i+1)
  ax = plt.imshow(rgb_img)
  ax = plt.title(f'{trainset_0.targets[img_index]}: {label_dict[trainset_0.targets[img_index]]}')

# %% [markdown]
# ### Set up GPU & functions

# %%
# Connect to drive to save models
from google.colab import drive
drive.mount('/content/gdrive')
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %%
# Set up GPU
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"
print(f"Using {device}.")
if gpu_info.find('failed') >= 0:
  if device == "cpu":
    print('Not connected to a GPU')
else:
  if device == "cuda":
    print(gpu_info)
# Out:
# Using cuda.
# Wed Feb  1 10:29:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def train_validate_model(train_loader,valid_loader,model,epochs,optimizer, save_pth):
  '''
  Input: train & validation data, model and its parameters, path to save model
  Output: - the model is trained and validated on the provided data
          - training & validation accuracy & loss are recorded and returned as output
  '''
  train_acc = []
  train_loss = []
  val_acc = []
  val_loss = []

  for epoch in range(epochs):
      # Training
      total_train=0
      correct_train = 0
      for i, (images, labels) in enumerate(train_loader):  
          # Move tensors to the configured device
          images = images.to(device)
          labels = labels.to(device)
          # Forward pass
          outputs = model(images)
          loss = criterion(outputs, labels)
          # Backward and optimize
          optimizer.zero_grad()
          loss.backward()
          optimizer.step()
          # Calculate train accuracy
          _, predicted = torch.max(outputs.data, 1)
          total_train += labels.size(0)
          correct_train += (predicted == labels).sum().item()
          del images, labels, outputs
      # Record accuracy & loss
      train_loss.append(loss.item())
      train_acc.append(100 * correct_train / total_train)
      print ('Epoch [{}/{}], Training loss: {:.4f}, Train accuracy: {}' 
                   .format(epoch+1, epochs, loss.item(),100 * correct_train / total_train))
            
      # Validation
      with torch.no_grad():
          correct_val = 0
          total_val = 0
          for images, labels in valid_loader:
              # Move tensors to the configured device
              images = images.to(device)
              labels = labels.to(device)
              # Predict label
              outputs = model(images)
              # Calculate loss & accuracy
              loss=criterion(outputs, labels)
              _, predicted = torch.max(outputs.data, 1)
              total_val += labels.size(0)
              correct_val += (predicted == labels).sum().item()
              del images, labels, outputs
          # Record accuracy & loss
          val_loss.append(loss.item())
          val_acc.append(100 * correct_val / total_val)
          print('Validation loss: {:.4f}, Validation accuracy: {} %'.format(loss.item(), 100 * correct_val / total_val))
      # Save model by epoch 
      torch.save(model.state_dict(), f'{save_pth}/{epoch+1}epoch.pt')

  return train_acc, train_loss, val_acc, val_loss

# %%
def plot_acc_loss(epoch_list, train_acc, train_loss, val_acc, val_loss):
  '''
  Input: list of epoch number, list of training & validation accuracy & loss
  Output: 2 graphs of loss and accuracy by epoch and train/validation
  '''
  f, (ax1, ax2) = plt.subplots(1,2,figsize=(15, 5))
  # Plot loss graph
  ax1.plot(epoch_list, train_loss, label = "Training")
  ax1.plot(epoch_list, val_loss, label = "Validation")
  ax1.set_xlabel("Epoch")
  ax1.set_ylabel("Cross entrophy loss")
  ax1.legend()
  # Plot accuracy graph
  ax2.plot(epoch_list, train_acc, label = "Training")
  ax2.plot(epoch_list, val_acc, label = "Validation")
  ax2.set_xlabel("Epoch")
  ax2.set_ylabel("Accuracy score")
  ax2.legend()

# %%
def plot_acc_lr(epochs,lr_list,train_acc,val_acc):
  '''
  Input: number of epoch, list of training & validation accuracy
  Output: 2 line graphs of accuracy by learning rate over epoch range for train/validation
  '''
  # Create epoch list
  epoch_list = []
  for epoch in range(epochs):
    epoch_list.append(epoch)
  
  f, (ax1, ax2) = plt.subplots(1,2,figsize=(15, 5))
  # Plot accuracy by lr for training set
  for i in range(len(lr_list)):
    ax1.plot(epoch_list, train_acc[i], label = f"lr = {lr_list[i]}")
  ax1.set_xlabel("Epoch")
  ax1.set_ylabel("Accuracy score")
  ax1.set_title("Traning")
  ax1.legend()
  # Plot accuracy by lr for validating set
  for i in range(len(lr_list)):
    ax2.plot(epoch_list, val_acc[i], label = f"lr = {lr_list[i]}")
  ax2.set_xlabel("Epoch")
  ax2.set_ylabel("Accuracy score")
  ax2.set_title("Validation")
  ax2.legend()

# %% [markdown]
# ### 1. VGG16

# %% [markdown]
# #### 1.1 Architecture

# %%
# Define VGG16 network
class VGG16(nn.Module):
    def __init__(self,num_classes=10):
        super(VGG16, self).__init__()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU())
        self.layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(), 
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer5 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer6 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU())
        self.layer7 = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer8 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer9 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer10 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.layer11 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer12 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU())
        self.layer13 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(1*1*512, 4096), # change to adapt to 32x32 image input
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out) # 16x16
        out = self.layer3(out)
        out = self.layer4(out) # 8x8
        out = self.layer5(out)
        out = self.layer6(out)
        out = self.layer7(out) # 4x4
        out = self.layer8(out)
        out = self.layer9(out)
        out = self.layer10(out) # 2x2
        out = self.layer11(out)
        out = self.layer12(out)
        out = self.layer13(out) # 1x1
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %% [markdown]
# #### 1.2 Basic transformation

# %%
# Define model parameters
lr = 0.001
epochs = 40
model = VGG16(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16'

# %%
# Train the model
vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss = train_validate_model(train_dataloader_0,val_dataloader_0,model,epochs,optimizer, save_path)
# Out:
# Epoch [1/40], Loss: 1.0948, Train accuracy: 48.118
# Loss: 1.2051, Validation accuracy: 63.62 %
# Epoch [2/40], Loss: 0.5714, Train accuracy: 69.72
# Loss: 0.8393, Validation accuracy: 72.99 %
# Epoch [3/40], Loss: 1.3463, Train accuracy: 77.926
# Loss: 0.8113, Validation accuracy: 76.03 %
# Epoch [4/40], Loss: 0.5150, Train accuracy: 82.986
# Loss: 0.9282, Validation accuracy: 79.0 %
# Epoch [5/40], Loss: 0.5152, Train accuracy: 86.462
# Loss: 1.0142, Validation accuracy: 80.72 %
# Epoch [6/40], Loss: 0.3525, Train accuracy: 89.464
# Loss: 0.8369, Validation accuracy: 80.82 %
# Epoch [7/40], Loss: 0.7896, Train accuracy: 91.2
# Loss: 0.8225, Validation accuracy: 80.86 %
# Epoch [8/40], Loss: 0.0500, Train accuracy: 93.394
# Loss: 0.8944, Validation accuracy: 81.77 %
# Epoch [9/40], Loss: 0.1567, Train accuracy: 94.814
# Loss: 1.5541, Validation accuracy: 80.82 %
# Epoch [10/40], Loss: 0.5589, Train accuracy: 95.462
# Loss: 1.2585, Validation accuracy: 82.12 %
# Epoch [11/40], Loss: 0.5326, Train accuracy: 96.222
# Loss: 1.6036, Validation accuracy: 82.35 %
# Epoch [12/40], Loss: 0.4637, Train accuracy: 97.158
# Loss: 1.0795, Validation accuracy: 81.94 %
# Epoch [13/40], Loss: 0.0458, Train accuracy: 97.526
# Loss: 1.3820, Validation accuracy: 82.06 %
# Epoch [14/40], Loss: 0.0050, Train accuracy: 97.788
# Loss: 1.5366, Validation accuracy: 82.61 %
# Epoch [15/40], Loss: 0.0021, Train accuracy: 98.022
# Loss: 1.7297, Validation accuracy: 82.99 %
# Epoch [16/40], Loss: 0.0479, Train accuracy: 98.48
# Loss: 1.1676, Validation accuracy: 83.26 %
# Epoch [17/40], Loss: 0.3106, Train accuracy: 98.534
# Loss: 1.2231, Validation accuracy: 82.84 %
# Epoch [18/40], Loss: 0.0071, Train accuracy: 98.732
# Loss: 1.3442, Validation accuracy: 83.5 %
# Epoch [19/40], Loss: 0.0022, Train accuracy: 98.71
# Loss: 1.2276, Validation accuracy: 83.39 %
# Epoch [20/40], Loss: 0.1326, Train accuracy: 98.876
# Loss: 1.9118, Validation accuracy: 83.86 %
# Epoch [21/40], Loss: 0.0381, Train accuracy: 99.1
# Loss: 2.1648, Validation accuracy: 84.02 %
# Epoch [22/40], Loss: 0.0316, Train accuracy: 99.074
# Loss: 2.4965, Validation accuracy: 82.91 %
# Epoch [23/40], Loss: 0.1020, Train accuracy: 99.18
# Loss: 1.8288, Validation accuracy: 83.6 %
# Epoch [24/40], Loss: 0.0086, Train accuracy: 99.278
# Loss: 1.8422, Validation accuracy: 84.15 %
# Epoch [25/40], Loss: 0.1811, Train accuracy: 99.276
# Loss: 1.5893, Validation accuracy: 83.92 %
# Epoch [26/40], Loss: 0.0010, Train accuracy: 99.38
# Loss: 1.9456, Validation accuracy: 83.42 %
# Epoch [27/40], Loss: 0.2592, Train accuracy: 99.276
# Loss: 1.1373, Validation accuracy: 83.83 %
# Epoch [28/40], Loss: 0.0007, Train accuracy: 99.542
# Loss: 1.3272, Validation accuracy: 84.22 %
# Epoch [29/40], Loss: 0.0023, Train accuracy: 99.516
# Loss: 2.1710, Validation accuracy: 84.33 %
# Epoch [30/40], Loss: 0.0426, Train accuracy: 99.468
# Loss: 1.8046, Validation accuracy: 84.76 %
# Epoch [31/40], Loss: 0.0005, Train accuracy: 99.522
# Loss: 1.4268, Validation accuracy: 83.61 %
# Epoch [32/40], Loss: 0.0392, Train accuracy: 99.52
# Loss: 2.0551, Validation accuracy: 84.73 %
# Epoch [33/40], Loss: 0.2352, Train accuracy: 99.472
# Loss: 1.8099, Validation accuracy: 83.58 %
# Epoch [34/40], Loss: 0.0266, Train accuracy: 99.682
# Loss: 2.2027, Validation accuracy: 84.77 %
# Epoch [35/40], Loss: 0.0007, Train accuracy: 99.704
# Loss: 1.5734, Validation accuracy: 84.33 %
# Epoch [36/40], Loss: 0.0236, Train accuracy: 99.686
# Loss: 2.1454, Validation accuracy: 83.92 %
# Epoch [37/40], Loss: 0.0014, Train accuracy: 99.59
# Loss: 1.8091, Validation accuracy: 83.71 %
# Epoch [38/40], Loss: 0.0032, Train accuracy: 99.628
# Loss: 1.6289, Validation accuracy: 84.33 %
# Epoch [39/40], Loss: 0.0035, Train accuracy: 99.758
# Loss: 1.7589, Validation accuracy: 84.15 %
# Epoch [40/40], Loss: 0.0012, Train accuracy: 99.756
# Loss: 1.6011, Validation accuracy: 84.79 %

# %%
# Plot loss and accuracy plot
epoch_list = []
for epoch in range(epochs):
  epoch_list.append(epoch)

plot_acc_loss(epoch_list, vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss)

# %% [markdown]
# #### 1.3 With normalization

# %%
# Define model parameters
lr = 0.001
epochs = 40
model = VGG16(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16'

# %%
# Train the model
vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss = train_validate_model(train_dataloader_1,val_dataloader_1,model,epochs,optimizer, save_path)
# Out:
# Epoch [1/40], Loss: 1.3305, Train accuracy: 48.254
# Loss: 1.0451, Validation accuracy: 63.07 %
# Epoch [2/40], Loss: 1.1556, Train accuracy: 70.1
# Loss: 1.0195, Validation accuracy: 73.84 %
# Epoch [3/40], Loss: 0.4437, Train accuracy: 77.88
# Loss: 0.9857, Validation accuracy: 76.59 %
# Epoch [4/40], Loss: 0.7290, Train accuracy: 83.074
# Loss: 1.1725, Validation accuracy: 78.6 %
# Epoch [5/40], Loss: 0.5819, Train accuracy: 86.564
# Loss: 0.8219, Validation accuracy: 80.44 %
# Epoch [6/40], Loss: 0.3292, Train accuracy: 89.53
# Loss: 1.1848, Validation accuracy: 80.4 %
# Epoch [7/40], Loss: 0.3960, Train accuracy: 91.516
# Loss: 0.9608, Validation accuracy: 80.37 %
# Epoch [8/40], Loss: 0.1651, Train accuracy: 93.138
# Loss: 1.0534, Validation accuracy: 81.04 %
# Epoch [9/40], Loss: 0.0721, Train accuracy: 94.584
# Loss: 0.9230, Validation accuracy: 81.72 %
# Epoch [10/40], Loss: 0.0728, Train accuracy: 95.732
# Loss: 1.6333, Validation accuracy: 81.88 %
# Epoch [11/40], Loss: 0.2938, Train accuracy: 96.29
# Loss: 1.6860, Validation accuracy: 81.89 %
# Epoch [12/40], Loss: 0.0063, Train accuracy: 97.058
# Loss: 0.9009, Validation accuracy: 82.56 %
# Epoch [13/40], Loss: 0.0412, Train accuracy: 97.602
# Loss: 0.8297, Validation accuracy: 82.2 %
# Epoch [14/40], Loss: 0.0580, Train accuracy: 97.778
# Loss: 1.4628, Validation accuracy: 82.55 %
# Epoch [15/40], Loss: 0.3759, Train accuracy: 97.998
# Loss: 1.1881, Validation accuracy: 82.44 %
# Epoch [16/40], Loss: 0.0064, Train accuracy: 98.14
# Loss: 1.2625, Validation accuracy: 83.27 %
# Epoch [17/40], Loss: 0.4000, Train accuracy: 98.56
# Loss: 1.3950, Validation accuracy: 82.94 %
# Epoch [18/40], Loss: 0.0043, Train accuracy: 98.672
# Loss: 1.3558, Validation accuracy: 82.51 %
# Epoch [19/40], Loss: 0.1733, Train accuracy: 98.954
# Loss: 1.3248, Validation accuracy: 83.22 %
# Epoch [20/40], Loss: 0.3387, Train accuracy: 98.996
# Loss: 1.6143, Validation accuracy: 83.42 %
# Epoch [21/40], Loss: 0.0095, Train accuracy: 98.97
# Loss: 1.0668, Validation accuracy: 82.61 %
# Epoch [22/40], Loss: 0.0025, Train accuracy: 99.148
# Loss: 2.1217, Validation accuracy: 82.71 %
# Epoch [23/40], Loss: 0.2236, Train accuracy: 99.09
# Loss: 1.9267, Validation accuracy: 83.24 %
# Epoch [24/40], Loss: 0.0104, Train accuracy: 99.218
# Loss: 2.0017, Validation accuracy: 83.22 %
# Epoch [25/40], Loss: 0.0205, Train accuracy: 99.366
# Loss: 1.5341, Validation accuracy: 83.64 %
# Epoch [26/40], Loss: 0.0008, Train accuracy: 99.29
# Loss: 1.5835, Validation accuracy: 83.33 %
# Epoch [27/40], Loss: 0.0064, Train accuracy: 99.378
# Loss: 2.6238, Validation accuracy: 83.76 %
# Epoch [28/40], Loss: 0.1272, Train accuracy: 99.456
# Loss: 1.1437, Validation accuracy: 83.61 %
# Epoch [29/40], Loss: 0.0082, Train accuracy: 99.464
# Loss: 1.7743, Validation accuracy: 83.99 %
# Epoch [30/40], Loss: 0.0092, Train accuracy: 99.546
# Loss: 1.5087, Validation accuracy: 83.5 %
# Epoch [31/40], Loss: 0.0012, Train accuracy: 99.462
# Loss: 1.6442, Validation accuracy: 83.23 %
# Epoch [32/40], Loss: 0.0004, Train accuracy: 99.596
# Loss: 1.3901, Validation accuracy: 83.67 %
# Epoch [33/40], Loss: 0.0124, Train accuracy: 99.478
# Loss: 1.8813, Validation accuracy: 83.95 %
# Epoch [34/40], Loss: 0.0204, Train accuracy: 99.52
# Loss: 1.7232, Validation accuracy: 83.78 %
# Epoch [35/40], Loss: 0.0001, Train accuracy: 99.722
# Loss: 2.2879, Validation accuracy: 84.29 %
# Epoch [36/40], Loss: 0.0000, Train accuracy: 99.634
# Loss: 1.8838, Validation accuracy: 84.46 %
# Epoch [37/40], Loss: 0.0000, Train accuracy: 99.624
# Loss: 1.3740, Validation accuracy: 84.38 %
# Epoch [38/40], Loss: 0.0003, Train accuracy: 99.684
# Loss: 1.8121, Validation accuracy: 84.13 %
# Epoch [39/40], Loss: 0.0099, Train accuracy: 99.55
# Loss: 1.5379, Validation accuracy: 84.0 %
# Epoch [40/40], Loss: 0.2161, Train accuracy: 99.746
# Loss: 2.0304, Validation accuracy: 84.45 %

# %%
# Plot loss and accuracy plot
epoch_list = []
for epoch in range(epochs):
  epoch_list.append(epoch)

plot_acc_loss(epoch_list, vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss)

# %% [markdown]
# #### 1.4 With normalization & augmentation

# %%
# Define model parameters
lr = 0.001
epochs = 40
model = VGG16(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16'

# %%
# Train the model
vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss = train_validate_model(train_dataloader_2,val_dataloader_1,model,epochs,optimizer, save_path)
# Out:
# Epoch [1/40], Loss: 1.5949, Train accuracy: 41.904
# Loss: 1.2364, Validation accuracy: 58.43 %
# Epoch [2/40], Loss: 1.2436, Train accuracy: 61.062
# Loss: 0.9243, Validation accuracy: 67.09 %
# Epoch [3/40], Loss: 0.7752, Train accuracy: 68.562
# Loss: 1.2465, Validation accuracy: 71.22 %
# Epoch [4/40], Loss: 0.5966, Train accuracy: 73.022
# Loss: 0.9770, Validation accuracy: 75.05 %
# Epoch [5/40], Loss: 0.4743, Train accuracy: 76.266
# Loss: 0.5167, Validation accuracy: 77.62 %
# Epoch [6/40], Loss: 0.4533, Train accuracy: 78.68
# Loss: 0.8035, Validation accuracy: 77.52 %
# Epoch [7/40], Loss: 0.2875, Train accuracy: 80.784
# Loss: 0.4673, Validation accuracy: 79.88 %
# Epoch [8/40], Loss: 0.7228, Train accuracy: 82.782
# Loss: 0.4802, Validation accuracy: 80.47 %
# Epoch [9/40], Loss: 0.7150, Train accuracy: 84.232
# Loss: 0.7361, Validation accuracy: 81.4 %
# Epoch [10/40], Loss: 0.4312, Train accuracy: 85.422
# Loss: 0.6073, Validation accuracy: 81.96 %
# Epoch [11/40], Loss: 0.5500, Train accuracy: 86.4
# Loss: 0.9117, Validation accuracy: 82.22 %
# Epoch [12/40], Loss: 0.5170, Train accuracy: 87.42
# Loss: 0.6458, Validation accuracy: 82.32 %
# Epoch [13/40], Loss: 0.1071, Train accuracy: 88.506
# Loss: 0.5447, Validation accuracy: 82.76 %
# Epoch [14/40], Loss: 0.7605, Train accuracy: 89.356
# Loss: 0.3917, Validation accuracy: 83.28 %
# Epoch [15/40], Loss: 0.6329, Train accuracy: 89.898
# Loss: 0.7248, Validation accuracy: 84.45 %
# Epoch [16/40], Loss: 0.1996, Train accuracy: 90.692
# Loss: 0.8123, Validation accuracy: 83.98 %
# Epoch [17/40], Loss: 0.1309, Train accuracy: 91.196
# Loss: 0.9220, Validation accuracy: 83.0 %
# Epoch [18/40], Loss: 0.1459, Train accuracy: 91.846
# Loss: 0.8007, Validation accuracy: 84.0 %
# Epoch [19/40], Loss: 0.0825, Train accuracy: 92.142
# Loss: 0.5188, Validation accuracy: 84.85 %
# Epoch [20/40], Loss: 0.3551, Train accuracy: 92.954
# Loss: 0.5695, Validation accuracy: 84.64 %
# Epoch [21/40], Loss: 0.3110, Train accuracy: 93.09
# Loss: 0.3853, Validation accuracy: 84.17 %
# Epoch [22/40], Loss: 0.4381, Train accuracy: 93.748
# Loss: 0.5112, Validation accuracy: 83.62 %
# Epoch [23/40], Loss: 0.1202, Train accuracy: 94.186
# Loss: 1.0540, Validation accuracy: 85.23 %
# Epoch [24/40], Loss: 0.7076, Train accuracy: 94.334
# Loss: 0.6336, Validation accuracy: 83.62 %
# Epoch [25/40], Loss: 0.0834, Train accuracy: 94.526
# Loss: 0.8887, Validation accuracy: 84.55 %
# Epoch [26/40], Loss: 0.0617, Train accuracy: 94.776
# Loss: 0.7067, Validation accuracy: 84.6 %
# Epoch [27/40], Loss: 0.1627, Train accuracy: 95.08
# Loss: 0.8041, Validation accuracy: 85.63 %
# Epoch [28/40], Loss: 0.0339, Train accuracy: 95.2
# Loss: 1.0547, Validation accuracy: 85.25 %
# Epoch [29/40], Loss: 0.3033, Train accuracy: 95.614
# Loss: 1.1407, Validation accuracy: 85.54 %
# Epoch [30/40], Loss: 0.3072, Train accuracy: 95.706
# Loss: 1.0701, Validation accuracy: 85.04 %
# Epoch [31/40], Loss: 0.1185, Train accuracy: 96.114
# Loss: 1.3841, Validation accuracy: 85.12 %
# Epoch [32/40], Loss: 0.0877, Train accuracy: 96.142
# Loss: 1.0313, Validation accuracy: 85.79 %
# Epoch [33/40], Loss: 0.2494, Train accuracy: 96.252
# Loss: 1.0448, Validation accuracy: 84.98 %
# Epoch [34/40], Loss: 0.1543, Train accuracy: 96.598
# Loss: 1.1779, Validation accuracy: 84.56 %
# Epoch [35/40], Loss: 0.0655, Train accuracy: 96.846
# Loss: 1.0139, Validation accuracy: 85.55 %
# Epoch [36/40], Loss: 0.0141, Train accuracy: 96.804
# Loss: 0.7735, Validation accuracy: 86.09 %
# Epoch [37/40], Loss: 0.3462, Train accuracy: 96.922
# Loss: 0.9202, Validation accuracy: 85.97 %
# Epoch [38/40], Loss: 0.0256, Train accuracy: 97.19
# Loss: 0.9926, Validation accuracy: 86.16 %
# Epoch [39/40], Loss: 0.0886, Train accuracy: 97.04
# Loss: 1.0669, Validation accuracy: 86.3 %
# Epoch [40/40], Loss: 0.0232, Train accuracy: 97.322
# Loss: 1.2346, Validation accuracy: 86.64 %

# %%
# Plot loss and accuracy plot
epoch_list = []
for epoch in range(epochs):
  epoch_list.append(epoch)

plot_acc_loss(epoch_list, vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss)

# %% [markdown]
# #### 1.5 With augmentation

# %%
# Define model parameters
lr = 0.001
epochs = 40
model = VGG16(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16'

# %%
# Train the model
vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss = train_validate_model(train_dataloader_3,val_dataloader_0,model,epochs,optimizer, save_path)
# Out:
# Epoch [1/40], Loss: 1.1863, Train accuracy: 41.53
# Loss: 1.3669, Validation accuracy: 55.05 %
# Epoch [2/40], Loss: 0.9308, Train accuracy: 60.724
# Loss: 1.2024, Validation accuracy: 66.4 %
# Epoch [3/40], Loss: 0.6970, Train accuracy: 68.726
# Loss: 1.1000, Validation accuracy: 71.66 %
# Epoch [4/40], Loss: 0.7621, Train accuracy: 73.264
# Loss: 0.9660, Validation accuracy: 75.04 %
# Epoch [5/40], Loss: 0.2750, Train accuracy: 76.366
# Loss: 1.0596, Validation accuracy: 77.61 %
# Epoch [6/40], Loss: 0.8071, Train accuracy: 79.186
# Loss: 0.9135, Validation accuracy: 79.19 %
# Epoch [7/40], Loss: 0.9425, Train accuracy: 81.04
# Loss: 1.1022, Validation accuracy: 79.96 %
# Epoch [8/40], Loss: 0.3931, Train accuracy: 82.952
# Loss: 0.8623, Validation accuracy: 80.39 %
# Epoch [9/40], Loss: 0.7980, Train accuracy: 84.332
# Loss: 0.9409, Validation accuracy: 81.55 %
# Epoch [10/40], Loss: 0.8682, Train accuracy: 85.636
# Loss: 0.8367, Validation accuracy: 82.76 %
# Epoch [11/40], Loss: 0.3068, Train accuracy: 86.602
# Loss: 0.9787, Validation accuracy: 82.87 %
# Epoch [12/40], Loss: 0.4584, Train accuracy: 87.402
# Loss: 0.7166, Validation accuracy: 83.99 %
# Epoch [13/40], Loss: 0.4779, Train accuracy: 88.616
# Loss: 0.5237, Validation accuracy: 83.48 %
# Epoch [14/40], Loss: 0.4563, Train accuracy: 89.204
# Loss: 0.6883, Validation accuracy: 83.18 %
# Epoch [15/40], Loss: 0.0522, Train accuracy: 89.972
# Loss: 1.1985, Validation accuracy: 83.97 %
# Epoch [16/40], Loss: 0.4368, Train accuracy: 90.442
# Loss: 1.5099, Validation accuracy: 84.08 %
# Epoch [17/40], Loss: 0.4862, Train accuracy: 91.162
# Loss: 0.8484, Validation accuracy: 83.88 %
# Epoch [18/40], Loss: 0.6403, Train accuracy: 91.848
# Loss: 1.0150, Validation accuracy: 83.65 %
# Epoch [19/40], Loss: 0.3548, Train accuracy: 92.428
# Loss: 0.8546, Validation accuracy: 84.68 %
# Epoch [20/40], Loss: 0.0971, Train accuracy: 92.918
# Loss: 0.6997, Validation accuracy: 84.43 %
# Epoch [21/40], Loss: 0.0427, Train accuracy: 93.386
# Loss: 0.9621, Validation accuracy: 84.62 %
# Epoch [22/40], Loss: 0.1938, Train accuracy: 93.53
# Loss: 0.9759, Validation accuracy: 84.54 %
# Epoch [23/40], Loss: 0.1136, Train accuracy: 93.838
# Loss: 1.3006, Validation accuracy: 84.59 %
# Epoch [24/40], Loss: 0.1118, Train accuracy: 94.034
# Loss: 0.7932, Validation accuracy: 84.79 %
# Epoch [25/40], Loss: 0.2075, Train accuracy: 94.626
# Loss: 0.8398, Validation accuracy: 84.75 %
# Epoch [26/40], Loss: 0.0190, Train accuracy: 94.854
# Loss: 1.1415, Validation accuracy: 85.04 %
# Epoch [27/40], Loss: 0.1360, Train accuracy: 95.21
# Loss: 1.1982, Validation accuracy: 85.52 %
# Epoch [28/40], Loss: 0.1321, Train accuracy: 95.544
# Loss: 1.0217, Validation accuracy: 85.37 %
# Epoch [29/40], Loss: 0.0684, Train accuracy: 95.402
# Loss: 1.1507, Validation accuracy: 85.51 %
# Epoch [30/40], Loss: 0.0253, Train accuracy: 95.996
# Loss: 0.9718, Validation accuracy: 85.07 %
# Epoch [31/40], Loss: 0.0870, Train accuracy: 96.136
# Loss: 1.1723, Validation accuracy: 85.75 %
# Epoch [32/40], Loss: 0.1689, Train accuracy: 96.176
# Loss: 0.8598, Validation accuracy: 85.91 %
# Epoch [33/40], Loss: 0.4369, Train accuracy: 96.268
# Loss: 1.4717, Validation accuracy: 85.74 %
# Epoch [34/40], Loss: 0.1019, Train accuracy: 96.634
# Loss: 0.8192, Validation accuracy: 85.71 %
# Epoch [35/40], Loss: 0.1655, Train accuracy: 96.816
# Loss: 1.2341, Validation accuracy: 85.82 %
# Epoch [36/40], Loss: 0.0098, Train accuracy: 96.794
# Loss: 1.2900, Validation accuracy: 85.47 %
# Epoch [37/40], Loss: 0.8033, Train accuracy: 97.06
# Loss: 0.5242, Validation accuracy: 85.77 %
# Epoch [38/40], Loss: 0.2077, Train accuracy: 97.164
# Loss: 1.3501, Validation accuracy: 85.55 %
# Epoch [39/40], Loss: 0.2198, Train accuracy: 97.07
# Loss: 1.2731, Validation accuracy: 85.67 %
# Epoch [40/40], Loss: 0.0075, Train accuracy: 97.364
# Loss: 0.5576, Validation accuracy: 86.07 %

# %%
# Plot loss and accuracy plot
epoch_list = []
for epoch in range(epochs):
  epoch_list.append(epoch)

plot_acc_loss(epoch_list, vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss)

# %% [markdown]
# #### 1.6 Tune the hyperparameters

# %%
# Using SGD and change learning rate
lr_list = [0.1, 0.01, 0.0001, 0.001]
vgg16_train_acc=[]
vgg16_train_loss=[]
vgg16_val_acc=[]
vgg16_val_loss=[]

for lr in lr_list:
  print(f"=========== lr = {lr} ==========")
  epochs = 60
  model = VGG16(10).to(device)
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
  save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16/SGD'
  train_acc, train_loss, val_acc, val_loss = train_validate_model(train_dataloader_2,val_dataloader_1,model,epochs,optimizer, save_path)
  vgg16_train_acc.append(train_acc)
  vgg16_train_loss.append(train_loss)
  vgg16_val_acc.append(val_acc)
  vgg16_val_loss.append(val_loss)
# Out:
# =========== lr = 0.1 ==========
# Epoch [1/60], Training loss: 1.8660, Train accuracy: 12.962
# Validation loss: 2.0207, Validation accuracy: 18.58 %
# Epoch [2/60], Training loss: 1.8737, Train accuracy: 20.046
# Validation loss: 1.7407, Validation accuracy: 23.54 %
# Epoch [3/60], Training loss: 1.8150, Train accuracy: 24.634
# Validation loss: 1.8483, Validation accuracy: 27.3 %
# Epoch [4/60], Training loss: 1.9175, Train accuracy: 28.732
# Validation loss: 1.8787, Validation accuracy: 33.28 %
# Epoch [5/60], Training loss: 1.6514, Train accuracy: 31.796
# Validation loss: 1.8471, Validation accuracy: 34.53 %
# Epoch [6/60], Training loss: 2.0852, Train accuracy: 34.526
# Validation loss: 2.1869, Validation accuracy: 37.42 %
# Epoch [7/60], Training loss: 1.8900, Train accuracy: 38.164
# Validation loss: 1.8881, Validation accuracy: 39.24 %
# Epoch [8/60], Training loss: 2.2342, Train accuracy: 40.696
# Validation loss: 1.5561, Validation accuracy: 43.3 %
# Epoch [9/60], Training loss: 1.6381, Train accuracy: 43.504
# Validation loss: 1.8828, Validation accuracy: 47.64 %
# Epoch [10/60], Training loss: 1.3670, Train accuracy: 45.528
# Validation loss: 1.3083, Validation accuracy: 48.31 %
# Epoch [11/60], Training loss: 1.5733, Train accuracy: 47.598
# Validation loss: 2.0047, Validation accuracy: 49.58 %
# Epoch [12/60], Training loss: 1.1145, Train accuracy: 48.194
# Validation loss: 1.5863, Validation accuracy: 51.9 %
# Epoch [13/60], Training loss: 1.3755, Train accuracy: 50.024
# Validation loss: 1.7875, Validation accuracy: 50.16 %
# Epoch [14/60], Training loss: 1.1440, Train accuracy: 51.472
# Validation loss: 1.3691, Validation accuracy: 54.65 %
# Epoch [15/60], Training loss: 1.5763, Train accuracy: 52.548
# Validation loss: 1.8897, Validation accuracy: 54.18 %
# Epoch [16/60], Training loss: 1.5155, Train accuracy: 52.75
# Validation loss: 1.5832, Validation accuracy: 54.47 %
# Epoch [17/60], Training loss: 1.7651, Train accuracy: 54.078
# Validation loss: 1.2360, Validation accuracy: 57.08 %
# Epoch [18/60], Training loss: 0.6094, Train accuracy: 55.028
# Validation loss: 1.3235, Validation accuracy: 55.14 %
# Epoch [19/60], Training loss: 1.3184, Train accuracy: 56.426
# Validation loss: 2.3247, Validation accuracy: 58.57 %
# Epoch [20/60], Training loss: 1.0033, Train accuracy: 57.572
# Validation loss: 1.8310, Validation accuracy: 57.72 %
# Epoch [21/60], Training loss: 1.1017, Train accuracy: 57.31
# Validation loss: 1.5728, Validation accuracy: 59.56 %
# Epoch [22/60], Training loss: 1.5360, Train accuracy: 58.38
# Validation loss: 1.6408, Validation accuracy: 61.22 %
# Epoch [23/60], Training loss: 1.0982, Train accuracy: 59.736
# Validation loss: 2.0340, Validation accuracy: 59.21 %
# Epoch [24/60], Training loss: 1.9944, Train accuracy: 59.826
# Validation loss: 1.7788, Validation accuracy: 61.2 %
# Epoch [25/60], Training loss: 1.2399, Train accuracy: 60.556
# Validation loss: 2.2391, Validation accuracy: 61.53 %
# Epoch [26/60], Training loss: 1.2933, Train accuracy: 61.024
# Validation loss: 1.9014, Validation accuracy: 58.07 %
# Epoch [27/60], Training loss: 1.1848, Train accuracy: 61.582
# Validation loss: 1.5552, Validation accuracy: 64.57 %
# Epoch [28/60], Training loss: 1.3302, Train accuracy: 62.088
# Validation loss: 1.5208, Validation accuracy: 60.39 %
# Epoch [29/60], Training loss: 1.1655, Train accuracy: 62.6
# Validation loss: 1.4534, Validation accuracy: 62.13 %
# Epoch [30/60], Training loss: 0.6155, Train accuracy: 62.876
# Validation loss: 1.7273, Validation accuracy: 62.77 %
# Epoch [31/60], Training loss: 0.6148, Train accuracy: 63.076
# Validation loss: 1.7288, Validation accuracy: 65.02 %
# Epoch [32/60], Training loss: 0.9473, Train accuracy: 64.262
# Validation loss: 1.5075, Validation accuracy: 64.46 %
# Epoch [33/60], Training loss: 2.0660, Train accuracy: 64.284
# Validation loss: 1.7082, Validation accuracy: 65.58 %
# Epoch [34/60], Training loss: 1.2330, Train accuracy: 64.694
# Validation loss: 1.1239, Validation accuracy: 65.77 %
# Epoch [35/60], Training loss: 1.0294, Train accuracy: 65.39
# Validation loss: 1.1343, Validation accuracy: 62.1 %
# Epoch [36/60], Training loss: 1.5767, Train accuracy: 65.698
# Validation loss: 1.1027, Validation accuracy: 65.29 %
# Epoch [37/60], Training loss: 1.2335, Train accuracy: 65.266
# Validation loss: 0.9850, Validation accuracy: 64.99 %
# Epoch [38/60], Training loss: 1.0669, Train accuracy: 65.486
# Validation loss: 1.4752, Validation accuracy: 67.43 %
# Epoch [39/60], Training loss: 1.2697, Train accuracy: 66.624
# Validation loss: 1.1588, Validation accuracy: 64.79 %
# Epoch [40/60], Training loss: 1.1263, Train accuracy: 66.122
# Validation loss: 0.9056, Validation accuracy: 66.15 %
# Epoch [41/60], Training loss: 2.1495, Train accuracy: 67.312
# Validation loss: 1.2351, Validation accuracy: 67.5 %
# Epoch [42/60], Training loss: 0.8031, Train accuracy: 67.48
# Validation loss: 1.4664, Validation accuracy: 67.56 %
# Epoch [43/60], Training loss: 0.7186, Train accuracy: 67.07
# Validation loss: 1.2841, Validation accuracy: 66.75 %
# Epoch [44/60], Training loss: 2.0101, Train accuracy: 67.428
# Validation loss: 1.3797, Validation accuracy: 65.61 %
# Epoch [45/60], Training loss: 1.0612, Train accuracy: 68.178
# Validation loss: 1.3850, Validation accuracy: 68.22 %
# Epoch [46/60], Training loss: 0.6206, Train accuracy: 68.446
# Validation loss: 1.3464, Validation accuracy: 67.28 %
# Epoch [47/60], Training loss: 0.9973, Train accuracy: 68.572
# Validation loss: 1.0451, Validation accuracy: 63.6 %
# Epoch [48/60], Training loss: 1.1207, Train accuracy: 69.116
# Validation loss: 0.8823, Validation accuracy: 66.46 %
# Epoch [49/60], Training loss: 0.9899, Train accuracy: 68.382
# Validation loss: 1.0389, Validation accuracy: 66.22 %
# Epoch [50/60], Training loss: 0.6350, Train accuracy: 68.77
# Validation loss: 1.2974, Validation accuracy: 67.73 %
# Epoch [51/60], Training loss: 1.1634, Train accuracy: 69.114
# Validation loss: 1.2443, Validation accuracy: 64.93 %
# Epoch [52/60], Training loss: 0.9067, Train accuracy: 69.61
# Validation loss: 1.0404, Validation accuracy: 70.14 %
# Epoch [53/60], Training loss: 0.9623, Train accuracy: 69.472
# Validation loss: 1.6445, Validation accuracy: 68.02 %
# Epoch [54/60], Training loss: 0.5078, Train accuracy: 69.182
# Validation loss: 0.7189, Validation accuracy: 70.17 %
# Epoch [55/60], Training loss: 0.8484, Train accuracy: 70.474
# Validation loss: 1.4682, Validation accuracy: 69.07 %
# Epoch [56/60], Training loss: 0.5230, Train accuracy: 70.832
# Validation loss: 1.1474, Validation accuracy: 69.71 %
# Epoch [57/60], Training loss: 2.7167, Train accuracy: 68.59
# Validation loss: 1.1830, Validation accuracy: 62.93 %
# Epoch [58/60], Training loss: 0.9786, Train accuracy: 67.944
# Validation loss: 1.6479, Validation accuracy: 70.99 %
# Epoch [59/60], Training loss: 1.1263, Train accuracy: 70.122
# Validation loss: 0.8039, Validation accuracy: 68.76 %
# Epoch [60/60], Training loss: 0.5661, Train accuracy: 70.048
# Validation loss: 1.1853, Validation accuracy: 68.47 %
# =========== lr = 0.01 ==========
# Epoch [1/60], Training loss: 1.7847, Train accuracy: 27.296
# Validation loss: 2.0825, Validation accuracy: 39.85 %
# Epoch [2/60], Training loss: 2.0706, Train accuracy: 47.068
# Validation loss: 1.2202, Validation accuracy: 57.09 %
# Epoch [3/60], Training loss: 1.7053, Train accuracy: 59.228
# Validation loss: 1.0357, Validation accuracy: 64.84 %
# Epoch [4/60], Training loss: 1.8233, Train accuracy: 66.35
# Validation loss: 0.8380, Validation accuracy: 70.94 %
# Epoch [5/60], Training loss: 0.4266, Train accuracy: 70.606
# Validation loss: 0.7620, Validation accuracy: 73.89 %
# Epoch [6/60], Training loss: 1.0928, Train accuracy: 73.936
# Validation loss: 0.9523, Validation accuracy: 76.13 %
# Epoch [7/60], Training loss: 1.0114, Train accuracy: 76.41
# Validation loss: 0.5917, Validation accuracy: 78.2 %
# Epoch [8/60], Training loss: 0.4129, Train accuracy: 78.612
# Validation loss: 0.9640, Validation accuracy: 77.08 %
# Epoch [9/60], Training loss: 0.5330, Train accuracy: 80.396
# Validation loss: 0.7847, Validation accuracy: 80.41 %
# Epoch [10/60], Training loss: 0.3529, Train accuracy: 81.964
# Validation loss: 0.8427, Validation accuracy: 81.11 %
# Epoch [11/60], Training loss: 0.5860, Train accuracy: 83.276
# Validation loss: 0.8567, Validation accuracy: 81.88 %
# Epoch [12/60], Training loss: 0.4806, Train accuracy: 84.52
# Validation loss: 0.9738, Validation accuracy: 83.12 %
# Epoch [13/60], Training loss: 0.3439, Train accuracy: 85.66
# Validation loss: 0.8974, Validation accuracy: 82.31 %
# Epoch [14/60], Training loss: 0.3293, Train accuracy: 86.522
# Validation loss: 0.9173, Validation accuracy: 83.11 %
# Epoch [15/60], Training loss: 0.3417, Train accuracy: 87.63
# Validation loss: 0.5827, Validation accuracy: 83.51 %
# Epoch [16/60], Training loss: 0.1576, Train accuracy: 88.192
# Validation loss: 0.6280, Validation accuracy: 84.32 %
# Epoch [17/60], Training loss: 0.4925, Train accuracy: 89.082
# Validation loss: 0.5593, Validation accuracy: 83.98 %
# Epoch [18/60], Training loss: 0.3704, Train accuracy: 89.648
# Validation loss: 0.9794, Validation accuracy: 85.33 %
# Epoch [19/60], Training loss: 0.5004, Train accuracy: 90.198
# Validation loss: 0.7820, Validation accuracy: 85.0 %
# Epoch [20/60], Training loss: 0.1150, Train accuracy: 90.93
# Validation loss: 0.6466, Validation accuracy: 85.77 %
# Epoch [21/60], Training loss: 0.0114, Train accuracy: 91.442
# Validation loss: 0.6928, Validation accuracy: 86.18 %
# Epoch [22/60], Training loss: 0.4489, Train accuracy: 91.89
# Validation loss: 0.7690, Validation accuracy: 86.34 %
# Epoch [23/60], Training loss: 0.1681, Train accuracy: 92.22
# Validation loss: 0.4673, Validation accuracy: 85.56 %
# Epoch [24/60], Training loss: 0.5670, Train accuracy: 92.98
# Validation loss: 1.2666, Validation accuracy: 85.93 %
# Epoch [25/60], Training loss: 0.1697, Train accuracy: 93.028
# Validation loss: 0.8885, Validation accuracy: 86.29 %
# Epoch [26/60], Training loss: 0.0214, Train accuracy: 93.6
# Validation loss: 0.8004, Validation accuracy: 86.84 %
# Epoch [27/60], Training loss: 0.2983, Train accuracy: 93.778
# Validation loss: 0.8753, Validation accuracy: 86.8 %
# Epoch [28/60], Training loss: 0.5671, Train accuracy: 94.016
# Validation loss: 0.9463, Validation accuracy: 86.23 %
# Epoch [29/60], Training loss: 0.1013, Train accuracy: 94.474
# Validation loss: 0.5268, Validation accuracy: 87.06 %
# Epoch [30/60], Training loss: 0.4223, Train accuracy: 94.84
# Validation loss: 0.2917, Validation accuracy: 86.6 %
# Epoch [31/60], Training loss: 0.3280, Train accuracy: 94.794
# Validation loss: 0.6474, Validation accuracy: 86.72 %
# Epoch [32/60], Training loss: 0.1551, Train accuracy: 95.132
# Validation loss: 1.0967, Validation accuracy: 86.8 %
# Epoch [33/60], Training loss: 0.0162, Train accuracy: 95.476
# Validation loss: 0.8521, Validation accuracy: 87.26 %
# Epoch [34/60], Training loss: 0.0086, Train accuracy: 95.788
# Validation loss: 0.7798, Validation accuracy: 86.59 %
# Epoch [35/60], Training loss: 0.0170, Train accuracy: 96.062
# Validation loss: 1.3597, Validation accuracy: 86.36 %
# Epoch [36/60], Training loss: 0.1111, Train accuracy: 96.124
# Validation loss: 0.8267, Validation accuracy: 87.61 %
# Epoch [37/60], Training loss: 0.4150, Train accuracy: 96.186
# Validation loss: 0.8187, Validation accuracy: 86.95 %
# Epoch [38/60], Training loss: 0.0609, Train accuracy: 96.48
# Validation loss: 1.0575, Validation accuracy: 87.71 %
# Epoch [39/60], Training loss: 0.0364, Train accuracy: 96.55
# Validation loss: 0.8463, Validation accuracy: 86.94 %
# Epoch [40/60], Training loss: 0.5109, Train accuracy: 96.82
# Validation loss: 1.1088, Validation accuracy: 86.91 %
# Epoch [41/60], Training loss: 0.0124, Train accuracy: 97.042
# Validation loss: 0.7229, Validation accuracy: 86.82 %
# Epoch [42/60], Training loss: 0.0047, Train accuracy: 96.976
# Validation loss: 0.7891, Validation accuracy: 86.94 %
# Epoch [43/60], Training loss: 0.0118, Train accuracy: 97.112
# Validation loss: 1.3586, Validation accuracy: 87.44 %
# Epoch [44/60], Training loss: 0.0044, Train accuracy: 97.222
# Validation loss: 0.7950, Validation accuracy: 87.56 %
# Epoch [45/60], Training loss: 0.1505, Train accuracy: 97.322
# Validation loss: 0.8635, Validation accuracy: 86.84 %
# Epoch [46/60], Training loss: 0.0129, Train accuracy: 97.394
# Validation loss: 1.1475, Validation accuracy: 87.65 %
# Epoch [47/60], Training loss: 0.0520, Train accuracy: 97.606
# Validation loss: 1.3863, Validation accuracy: 87.87 %
# Epoch [48/60], Training loss: 0.1090, Train accuracy: 97.606
# Validation loss: 1.2643, Validation accuracy: 87.82 %
# Epoch [49/60], Training loss: 0.0021, Train accuracy: 97.76
# Validation loss: 1.3450, Validation accuracy: 86.91 %
# Epoch [50/60], Training loss: 0.0594, Train accuracy: 97.828
# Validation loss: 1.1299, Validation accuracy: 87.45 %
# Epoch [51/60], Training loss: 0.0334, Train accuracy: 97.998
# Validation loss: 1.0597, Validation accuracy: 87.87 %
# Epoch [52/60], Training loss: 0.1476, Train accuracy: 97.992
# Validation loss: 1.0204, Validation accuracy: 87.64 %
# Epoch [53/60], Training loss: 0.0028, Train accuracy: 98.032
# Validation loss: 1.2950, Validation accuracy: 88.27 %
# Epoch [54/60], Training loss: 0.4356, Train accuracy: 98.238
# Validation loss: 0.9612, Validation accuracy: 88.19 %
# Epoch [55/60], Training loss: 0.0015, Train accuracy: 98.134
# Validation loss: 1.5204, Validation accuracy: 87.52 %
# Epoch [56/60], Training loss: 0.0123, Train accuracy: 98.202
# Validation loss: 0.9154, Validation accuracy: 87.89 %
# Epoch [57/60], Training loss: 0.0734, Train accuracy: 98.278
# Validation loss: 1.5713, Validation accuracy: 88.39 %
# Epoch [58/60], Training loss: 0.0060, Train accuracy: 98.414
# Validation loss: 1.1705, Validation accuracy: 88.08 %
# Epoch [59/60], Training loss: 0.0012, Train accuracy: 98.366
# Validation loss: 1.2597, Validation accuracy: 88.05 %
# Epoch [60/60], Training loss: 0.0011, Train accuracy: 98.396
# Validation loss: 0.9679, Validation accuracy: 88.07 %
# =========== lr = 0.0001 ==========
# Epoch [1/60], Training loss: 1.6042, Train accuracy: 25.078
# Validation loss: 1.6093, Validation accuracy: 36.75 %
# Epoch [2/60], Training loss: 1.2645, Train accuracy: 41.298
# Validation loss: 1.4178, Validation accuracy: 48.72 %
# Epoch [3/60], Training loss: 1.4012, Train accuracy: 50.862
# Validation loss: 1.3821, Validation accuracy: 55.9 %
# Epoch [4/60], Training loss: 0.9452, Train accuracy: 57.882
# Validation loss: 1.4727, Validation accuracy: 60.13 %
# Epoch [5/60], Training loss: 1.1377, Train accuracy: 62.364
# Validation loss: 1.2225, Validation accuracy: 63.26 %
# Epoch [6/60], Training loss: 0.7890, Train accuracy: 65.678
# Validation loss: 0.9659, Validation accuracy: 65.83 %
# Epoch [7/60], Training loss: 1.1022, Train accuracy: 68.364
# Validation loss: 0.9722, Validation accuracy: 68.68 %
# Epoch [8/60], Training loss: 0.8346, Train accuracy: 70.6
# Validation loss: 0.9385, Validation accuracy: 70.08 %
# Epoch [9/60], Training loss: 0.7220, Train accuracy: 72.798
# Validation loss: 0.8728, Validation accuracy: 70.88 %
# Epoch [10/60], Training loss: 0.5537, Train accuracy: 74.9
# Validation loss: 0.8699, Validation accuracy: 72.12 %
# Epoch [11/60], Training loss: 0.5606, Train accuracy: 76.626
# Validation loss: 1.0743, Validation accuracy: 72.69 %
# Epoch [12/60], Training loss: 1.0874, Train accuracy: 77.932
# Validation loss: 1.0119, Validation accuracy: 73.53 %
# Epoch [13/60], Training loss: 1.3839, Train accuracy: 79.386
# Validation loss: 0.8908, Validation accuracy: 74.66 %
# Epoch [14/60], Training loss: 0.6192, Train accuracy: 80.794
# Validation loss: 0.9304, Validation accuracy: 74.23 %
# Epoch [15/60], Training loss: 0.7254, Train accuracy: 82.114
# Validation loss: 1.3288, Validation accuracy: 75.07 %
# Epoch [16/60], Training loss: 0.3614, Train accuracy: 82.96
# Validation loss: 0.9912, Validation accuracy: 75.93 %
# Epoch [17/60], Training loss: 1.1876, Train accuracy: 84.112
# Validation loss: 0.8935, Validation accuracy: 76.61 %
# Epoch [18/60], Training loss: 0.7156, Train accuracy: 85.176
# Validation loss: 1.2130, Validation accuracy: 76.29 %
# Epoch [19/60], Training loss: 1.1882, Train accuracy: 86.182
# Validation loss: 0.6641, Validation accuracy: 76.92 %
# Epoch [20/60], Training loss: 0.3209, Train accuracy: 86.502
# Validation loss: 0.8937, Validation accuracy: 76.44 %
# Epoch [21/60], Training loss: 0.7006, Train accuracy: 87.48
# Validation loss: 0.7793, Validation accuracy: 76.99 %
# Epoch [22/60], Training loss: 0.5320, Train accuracy: 88.182
# Validation loss: 0.8495, Validation accuracy: 77.53 %
# Epoch [23/60], Training loss: 0.3267, Train accuracy: 88.996
# Validation loss: 0.9627, Validation accuracy: 77.43 %
# Epoch [24/60], Training loss: 0.1658, Train accuracy: 89.364
# Validation loss: 1.0670, Validation accuracy: 77.16 %
# Epoch [25/60], Training loss: 0.4748, Train accuracy: 89.838
# Validation loss: 0.7494, Validation accuracy: 76.94 %
# Epoch [26/60], Training loss: 0.1584, Train accuracy: 90.346
# Validation loss: 0.5608, Validation accuracy: 77.53 %
# Epoch [27/60], Training loss: 0.2354, Train accuracy: 90.964
# Validation loss: 0.5908, Validation accuracy: 77.89 %
# Epoch [28/60], Training loss: 0.6041, Train accuracy: 91.478
# Validation loss: 0.4753, Validation accuracy: 77.87 %
# Epoch [29/60], Training loss: 1.0413, Train accuracy: 91.876
# Validation loss: 0.4846, Validation accuracy: 78.2 %
# Epoch [30/60], Training loss: 0.3190, Train accuracy: 92.276
# Validation loss: 0.7838, Validation accuracy: 78.54 %
# Epoch [31/60], Training loss: 0.4165, Train accuracy: 92.742
# Validation loss: 0.8604, Validation accuracy: 78.63 %
# Epoch [32/60], Training loss: 0.1699, Train accuracy: 92.74
# Validation loss: 0.9482, Validation accuracy: 78.11 %
# Epoch [33/60], Training loss: 0.0954, Train accuracy: 93.328
# Validation loss: 1.0331, Validation accuracy: 78.52 %
# Epoch [34/60], Training loss: 0.0394, Train accuracy: 93.508
# Validation loss: 0.9233, Validation accuracy: 78.18 %
# Epoch [35/60], Training loss: 0.3254, Train accuracy: 94.01
# Validation loss: 0.6990, Validation accuracy: 78.61 %
# Epoch [36/60], Training loss: 0.3983, Train accuracy: 94.226
# Validation loss: 0.6415, Validation accuracy: 78.48 %
# Epoch [37/60], Training loss: 0.5710, Train accuracy: 94.2
# Validation loss: 0.7010, Validation accuracy: 78.63 %
# Epoch [38/60], Training loss: 0.0780, Train accuracy: 94.412
# Validation loss: 0.6726, Validation accuracy: 78.78 %
# Epoch [39/60], Training loss: 0.1131, Train accuracy: 94.734
# Validation loss: 0.8587, Validation accuracy: 79.29 %
# Epoch [40/60], Training loss: 0.0370, Train accuracy: 95.076
# Validation loss: 0.8780, Validation accuracy: 78.75 %
# Epoch [41/60], Training loss: 0.0415, Train accuracy: 95.158
# Validation loss: 1.0518, Validation accuracy: 78.61 %
# Epoch [42/60], Training loss: 0.1897, Train accuracy: 95.254
# Validation loss: 1.0336, Validation accuracy: 79.14 %
# Epoch [43/60], Training loss: 0.3856, Train accuracy: 95.462
# Validation loss: 0.6604, Validation accuracy: 79.43 %
# Epoch [44/60], Training loss: 0.0608, Train accuracy: 95.672
# Validation loss: 1.2586, Validation accuracy: 79.56 %
# Epoch [45/60], Training loss: 0.5177, Train accuracy: 95.828
# Validation loss: 0.9947, Validation accuracy: 79.22 %
# Epoch [46/60], Training loss: 0.6737, Train accuracy: 96.134
# Validation loss: 0.9085, Validation accuracy: 79.42 %
# Epoch [47/60], Training loss: 0.0307, Train accuracy: 96.124
# Validation loss: 1.4369, Validation accuracy: 79.37 %
# Epoch [48/60], Training loss: 0.0492, Train accuracy: 96.358
# Validation loss: 1.3389, Validation accuracy: 79.29 %
# Epoch [49/60], Training loss: 0.0278, Train accuracy: 96.438
# Validation loss: 0.7530, Validation accuracy: 79.35 %
# Epoch [50/60], Training loss: 0.5502, Train accuracy: 96.416
# Validation loss: 0.7940, Validation accuracy: 78.62 %
# Epoch [51/60], Training loss: 0.0463, Train accuracy: 96.674
# Validation loss: 0.9792, Validation accuracy: 79.86 %
# Epoch [52/60], Training loss: 0.0181, Train accuracy: 96.986
# Validation loss: 1.3819, Validation accuracy: 79.85 %
# Epoch [53/60], Training loss: 0.2277, Train accuracy: 96.89
# Validation loss: 0.8133, Validation accuracy: 79.6 %
# Epoch [54/60], Training loss: 0.0046, Train accuracy: 96.972
# Validation loss: 1.0214, Validation accuracy: 79.31 %
# Epoch [55/60], Training loss: 0.4772, Train accuracy: 96.994
# Validation loss: 0.4973, Validation accuracy: 79.13 %
# Epoch [56/60], Training loss: 0.1237, Train accuracy: 97.166
# Validation loss: 0.9426, Validation accuracy: 79.33 %
# Epoch [57/60], Training loss: 0.0620, Train accuracy: 97.36
# Validation loss: 1.3411, Validation accuracy: 79.77 %
# Epoch [58/60], Training loss: 0.0485, Train accuracy: 97.248
# Validation loss: 0.5535, Validation accuracy: 79.53 %
# Epoch [59/60], Training loss: 0.0139, Train accuracy: 97.332
# Validation loss: 0.8970, Validation accuracy: 79.35 %
# Epoch [60/60], Training loss: 0.0577, Train accuracy: 97.462
# Validation loss: 0.7255, Validation accuracy: 80.02 %
# =========== lr = 0.001 ==========
# Epoch [1/60], Training loss: 1.0473, Train accuracy: 41.438
# Validation loss: 1.5774, Validation accuracy: 55.31 %
# Epoch [2/60], Training loss: 1.5776, Train accuracy: 60.5
# Validation loss: 0.8757, Validation accuracy: 65.28 %
# Epoch [3/60], Training loss: 0.9350, Train accuracy: 68.578
# Validation loss: 1.0442, Validation accuracy: 72.34 %
# Epoch [4/60], Training loss: 0.9807, Train accuracy: 73.386
# Validation loss: 0.8034, Validation accuracy: 75.37 %
# Epoch [5/60], Training loss: 0.7716, Train accuracy: 76.552
# Validation loss: 0.6832, Validation accuracy: 76.81 %
# Epoch [6/60], Training loss: 0.9559, Train accuracy: 78.884
# Validation loss: 0.6994, Validation accuracy: 79.27 %
# Epoch [7/60], Training loss: 0.6987, Train accuracy: 81.054
# Validation loss: 0.8390, Validation accuracy: 79.22 %
# Epoch [8/60], Training loss: 0.5617, Train accuracy: 83.042
# Validation loss: 0.4400, Validation accuracy: 80.61 %
# Epoch [9/60], Training loss: 0.5496, Train accuracy: 84.378
# Validation loss: 0.7674, Validation accuracy: 80.08 %
# Epoch [10/60], Training loss: 0.2614, Train accuracy: 85.818
# Validation loss: 1.0960, Validation accuracy: 81.41 %
# Epoch [11/60], Training loss: 0.6725, Train accuracy: 86.756
# Validation loss: 0.6801, Validation accuracy: 82.61 %
# Epoch [12/60], Training loss: 0.3462, Train accuracy: 87.624
# Validation loss: 0.6015, Validation accuracy: 82.87 %
# Epoch [13/60], Training loss: 0.5250, Train accuracy: 88.72
# Validation loss: 0.8932, Validation accuracy: 83.14 %
# Epoch [14/60], Training loss: 0.1108, Train accuracy: 89.36
# Validation loss: 0.8977, Validation accuracy: 83.59 %
# Epoch [15/60], Training loss: 0.4971, Train accuracy: 90.028
# Validation loss: 0.7192, Validation accuracy: 83.19 %
# Epoch [16/60], Training loss: 0.2283, Train accuracy: 90.67
# Validation loss: 0.4789, Validation accuracy: 83.47 %
# Epoch [17/60], Training loss: 0.1379, Train accuracy: 91.36
# Validation loss: 0.9207, Validation accuracy: 84.91 %
# Epoch [18/60], Training loss: 0.1568, Train accuracy: 91.84
# Validation loss: 0.7663, Validation accuracy: 84.33 %
# Epoch [19/60], Training loss: 0.3495, Train accuracy: 92.326
# Validation loss: 0.5607, Validation accuracy: 83.97 %
# Epoch [20/60], Training loss: 0.5662, Train accuracy: 93.0
# Validation loss: 0.9992, Validation accuracy: 84.95 %
# Epoch [21/60], Training loss: 0.1637, Train accuracy: 93.274
# Validation loss: 0.8529, Validation accuracy: 84.93 %
# Epoch [22/60], Training loss: 0.4529, Train accuracy: 93.64
# Validation loss: 0.8851, Validation accuracy: 85.15 %
# Epoch [23/60], Training loss: 0.1558, Train accuracy: 94.032
# Validation loss: 0.8153, Validation accuracy: 84.84 %
# Epoch [24/60], Training loss: 0.1715, Train accuracy: 94.36
# Validation loss: 1.0265, Validation accuracy: 84.65 %
# Epoch [25/60], Training loss: 0.0552, Train accuracy: 94.824
# Validation loss: 0.7336, Validation accuracy: 84.21 %
# Epoch [26/60], Training loss: 0.0510, Train accuracy: 95.058
# Validation loss: 0.5362, Validation accuracy: 84.34 %
# Epoch [27/60], Training loss: 0.1127, Train accuracy: 95.068
# Validation loss: 0.7393, Validation accuracy: 85.85 %
# Epoch [28/60], Training loss: 0.0187, Train accuracy: 95.502
# Validation loss: 0.7054, Validation accuracy: 85.19 %
# Epoch [29/60], Training loss: 0.0755, Train accuracy: 95.694
# Validation loss: 0.6906, Validation accuracy: 84.91 %
# Epoch [30/60], Training loss: 0.1213, Train accuracy: 95.796
# Validation loss: 0.7698, Validation accuracy: 85.41 %
# Epoch [31/60], Training loss: 0.0110, Train accuracy: 96.074
# Validation loss: 1.2068, Validation accuracy: 85.78 %
# Epoch [32/60], Training loss: 0.3429, Train accuracy: 96.302
# Validation loss: 0.6571, Validation accuracy: 85.5 %
# Epoch [33/60], Training loss: 0.0108, Train accuracy: 96.394
# Validation loss: 0.9003, Validation accuracy: 85.53 %
# Epoch [34/60], Training loss: 0.0120, Train accuracy: 96.462
# Validation loss: 0.7479, Validation accuracy: 86.15 %
# Epoch [35/60], Training loss: 0.2286, Train accuracy: 96.648
# Validation loss: 1.1849, Validation accuracy: 85.26 %
# Epoch [36/60], Training loss: 0.1426, Train accuracy: 96.78
# Validation loss: 0.8512, Validation accuracy: 85.47 %
# Epoch [37/60], Training loss: 0.1113, Train accuracy: 96.926
# Validation loss: 1.1214, Validation accuracy: 85.55 %
# Epoch [38/60], Training loss: 0.1950, Train accuracy: 96.994
# Validation loss: 1.3054, Validation accuracy: 85.86 %
# Epoch [39/60], Training loss: 0.0393, Train accuracy: 97.208
# Validation loss: 1.4252, Validation accuracy: 85.18 %
# Epoch [40/60], Training loss: 0.0043, Train accuracy: 97.224
# Validation loss: 1.2665, Validation accuracy: 85.33 %
# Epoch [41/60], Training loss: 0.0207, Train accuracy: 97.382
# Validation loss: 0.9064, Validation accuracy: 85.89 %
# Epoch [42/60], Training loss: 0.0087, Train accuracy: 97.474
# Validation loss: 1.1534, Validation accuracy: 85.73 %
# Epoch [43/60], Training loss: 0.0039, Train accuracy: 97.556
# Validation loss: 1.4195, Validation accuracy: 85.75 %
# Epoch [44/60], Training loss: 0.0051, Train accuracy: 97.69
# Validation loss: 0.8660, Validation accuracy: 86.0 %
# Epoch [45/60], Training loss: 0.1524, Train accuracy: 97.85
# Validation loss: 0.9647, Validation accuracy: 85.9 %
# Epoch [46/60], Training loss: 0.0989, Train accuracy: 97.828
# Validation loss: 1.1964, Validation accuracy: 86.82 %
# Epoch [47/60], Training loss: 0.0105, Train accuracy: 98.01
# Validation loss: 1.0261, Validation accuracy: 85.79 %
# Epoch [48/60], Training loss: 0.0005, Train accuracy: 98.052
# Validation loss: 1.5125, Validation accuracy: 85.66 %
# Epoch [49/60], Training loss: 0.0034, Train accuracy: 97.95
# Validation loss: 1.1388, Validation accuracy: 85.92 %
# Epoch [50/60], Training loss: 0.0109, Train accuracy: 98.152
# Validation loss: 1.3073, Validation accuracy: 86.41 %
# Epoch [51/60], Training loss: 0.0056, Train accuracy: 98.256
# Validation loss: 1.0899, Validation accuracy: 86.3 %
# Epoch [52/60], Training loss: 0.0028, Train accuracy: 98.36
# Validation loss: 0.9321, Validation accuracy: 85.95 %
# Epoch [53/60], Training loss: 0.0479, Train accuracy: 98.37
# Validation loss: 0.9236, Validation accuracy: 86.39 %
# Epoch [54/60], Training loss: 0.0022, Train accuracy: 98.218
# Validation loss: 1.5260, Validation accuracy: 86.5 %
# Epoch [55/60], Training loss: 0.0001, Train accuracy: 98.462
# Validation loss: 0.7175, Validation accuracy: 85.94 %
# Epoch [56/60], Training loss: 0.0488, Train accuracy: 98.47
# Validation loss: 0.9182, Validation accuracy: 86.44 %
# Epoch [57/60], Training loss: 0.0007, Train accuracy: 98.608
# Validation loss: 1.2141, Validation accuracy: 86.57 %
# Epoch [58/60], Training loss: 0.0015, Train accuracy: 98.56
# Validation loss: 0.8978, Validation accuracy: 86.35 %
# Epoch [59/60], Training loss: 0.0006, Train accuracy: 98.492
# Validation loss: 1.3199, Validation accuracy: 85.88 %
# Epoch [60/60], Training loss: 0.0175, Train accuracy: 98.554
# Validation loss: 0.7515, Validation accuracy: 86.51 %

# %%
# Accuracy comparision among the learning rates
plot_acc_lr(epochs,lr_list,vgg16_train_acc,vgg16_val_acc)

# %%
# Using Adam and change learning rate
lr_list = [0.1, 0.01, 0.0001, 0.001]
vgg16_train_acc=[]
vgg16_train_loss=[]
vgg16_val_acc=[]
vgg16_val_loss=[]

for lr in lr_list:
  print(f"=========== lr = {lr} ==========")
  epochs = 60
  model = VGG16(10).to(device)
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
  save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16/Adam'
  train_acc, train_loss, val_acc, val_loss = train_validate_model(train_dataloader_2,val_dataloader_1,model,epochs,optimizer, save_path)
  vgg16_train_acc.append(train_acc)
  vgg16_train_loss.append(train_loss)
  vgg16_val_acc.append(val_acc)
  vgg16_val_loss.append(val_loss)
# Out:
# =========== lr = 0.1 ==========
# Epoch [1/60], Training loss: 2.3555, Train accuracy: 10.138
# Validation loss: 2.3131, Validation accuracy: 10.0 %
# Epoch [2/60], Training loss: 2.2787, Train accuracy: 10.044
# Validation loss: 3.8356, Validation accuracy: 10.09 %
# Epoch [3/60], Training loss: 2.3051, Train accuracy: 10.04
# Validation loss: 2.3560, Validation accuracy: 9.99 %
# Epoch [4/60], Training loss: 2.2991, Train accuracy: 9.758
# Validation loss: 2.3920, Validation accuracy: 9.99 %
# Epoch [5/60], Training loss: 2.3377, Train accuracy: 10.152
# Validation loss: 2.2825, Validation accuracy: 10.0 %
# Epoch [6/60], Training loss: 2.2696, Train accuracy: 10.084
# Validation loss: 2.2951, Validation accuracy: 10.0 %
# Epoch [7/60], Training loss: 2.2986, Train accuracy: 9.924
# Validation loss: 2.2690, Validation accuracy: 10.0 %
# Epoch [8/60], Training loss: 2.5002, Train accuracy: 10.092
# Validation loss: 2.3658, Validation accuracy: 10.0 %
# Epoch [9/60], Training loss: 2.3265, Train accuracy: 9.918
# Validation loss: 2.3717, Validation accuracy: 10.0 %
# Epoch [10/60], Training loss: 2.3925, Train accuracy: 9.9
# Validation loss: 2.2698, Validation accuracy: 10.0 %
# Epoch [11/60], Training loss: 2.2687, Train accuracy: 9.892
# Validation loss: 2.2670, Validation accuracy: 10.0 %
# Epoch [12/60], Training loss: 2.2355, Train accuracy: 9.98
# Validation loss: 2.7377, Validation accuracy: 10.0 %
# Epoch [13/60], Training loss: 2.3203, Train accuracy: 9.946
# Validation loss: 2.3347, Validation accuracy: 10.0 %
# Epoch [14/60], Training loss: 2.2400, Train accuracy: 10.04
# Validation loss: 2.3610, Validation accuracy: 10.0 %
# Epoch [15/60], Training loss: 2.3812, Train accuracy: 10.082
# Validation loss: 2.3204, Validation accuracy: 10.0 %
# Epoch [16/60], Training loss: 2.2494, Train accuracy: 10.028
# Validation loss: 2.7203, Validation accuracy: 10.08 %
# Epoch [17/60], Training loss: 2.3263, Train accuracy: 9.822
# Validation loss: 2.3052, Validation accuracy: 10.0 %
# Epoch [18/60], Training loss: 2.2797, Train accuracy: 9.92
# Validation loss: 2.3035, Validation accuracy: 10.0 %
# Epoch [19/60], Training loss: 2.3364, Train accuracy: 9.814
# Validation loss: 2.2829, Validation accuracy: 10.0 %
# Epoch [20/60], Training loss: 6.6739, Train accuracy: 9.982
# Validation loss: 3.1038, Validation accuracy: 9.78 %
# Epoch [21/60], Training loss: 2.2701, Train accuracy: 10.124
# Validation loss: 7.7161, Validation accuracy: 10.54 %
# Epoch [22/60], Training loss: 2.2916, Train accuracy: 10.11
# Validation loss: 2.3055, Validation accuracy: 10.0 %
# Epoch [23/60], Training loss: 2.3191, Train accuracy: 10.194
# Validation loss: 2.3165, Validation accuracy: 10.0 %
# Epoch [24/60], Training loss: 2.2650, Train accuracy: 9.772
# Validation loss: 2.3581, Validation accuracy: 10.0 %
# Epoch [25/60], Training loss: 2.2664, Train accuracy: 10.012
# Validation loss: 2.2935, Validation accuracy: 10.0 %
# Epoch [26/60], Training loss: 2.3409, Train accuracy: 9.918
# Validation loss: 2.2901, Validation accuracy: 10.0 %
# Epoch [27/60], Training loss: 2.3581, Train accuracy: 10.006
# Validation loss: 2.3051, Validation accuracy: 10.0 %
# Epoch [28/60], Training loss: 2.3218, Train accuracy: 10.1
# Validation loss: 2.2531, Validation accuracy: 10.0 %
# Epoch [29/60], Training loss: 2.3006, Train accuracy: 9.892
# Validation loss: 2.3269, Validation accuracy: 10.0 %
# Epoch [30/60], Training loss: 2.3387, Train accuracy: 9.944
# Validation loss: 2.3786, Validation accuracy: 10.0 %
# Epoch [31/60], Training loss: 2.4161, Train accuracy: 9.816
# Validation loss: 3.8087, Validation accuracy: 10.03 %
# Epoch [32/60], Training loss: 2.2980, Train accuracy: 10.018
# Validation loss: 2.3074, Validation accuracy: 10.0 %
# Epoch [33/60], Training loss: 2.2924, Train accuracy: 9.898
# Validation loss: 2.3400, Validation accuracy: 10.0 %
# Epoch [34/60], Training loss: 2.3527, Train accuracy: 10.066
# Validation loss: 2.3262, Validation accuracy: 10.0 %
# Epoch [35/60], Training loss: 2.3867, Train accuracy: 10.182
# Validation loss: 2.3531, Validation accuracy: 10.0 %
# Epoch [36/60], Training loss: 2.3358, Train accuracy: 10.144
# Validation loss: 2.5612, Validation accuracy: 9.96 %
# Epoch [37/60], Training loss: 2.3393, Train accuracy: 9.78
# Validation loss: 2.2705, Validation accuracy: 10.0 %
# Epoch [38/60], Training loss: 2.3514, Train accuracy: 9.92
# Validation loss: 2.3277, Validation accuracy: 10.0 %
# Epoch [39/60], Training loss: 2.3190, Train accuracy: 10.064
# Validation loss: 2.3032, Validation accuracy: 10.0 %
# Epoch [40/60], Training loss: 2.3219, Train accuracy: 10.198
# Validation loss: 2.2990, Validation accuracy: 10.0 %
# Epoch [41/60], Training loss: 2.3056, Train accuracy: 10.23
# Validation loss: 7.0433, Validation accuracy: 10.08 %
# Epoch [42/60], Training loss: 2.4134, Train accuracy: 10.204
# Validation loss: 2.4073, Validation accuracy: 10.0 %
# Epoch [43/60], Training loss: 2.7808, Train accuracy: 10.418
# Validation loss: 2.2779, Validation accuracy: 10.0 %
# Epoch [44/60], Training loss: 2.3293, Train accuracy: 10.006
# Validation loss: 2.2911, Validation accuracy: 10.0 %
# Epoch [45/60], Training loss: 2.3404, Train accuracy: 10.09
# Validation loss: 2.3511, Validation accuracy: 10.0 %
# Epoch [46/60], Training loss: 2.3660, Train accuracy: 9.832
# Validation loss: 2.2817, Validation accuracy: 10.0 %
# Epoch [47/60], Training loss: 2.3996, Train accuracy: 9.928
# Validation loss: 5.7777, Validation accuracy: 9.72 %
# Epoch [48/60], Training loss: 2.2770, Train accuracy: 10.15
# Validation loss: 2.2467, Validation accuracy: 10.0 %
# Epoch [49/60], Training loss: 2.3205, Train accuracy: 10.278
# Validation loss: 2.2902, Validation accuracy: 10.0 %
# Epoch [50/60], Training loss: 2.3241, Train accuracy: 9.846
# Validation loss: 2.3218, Validation accuracy: 10.0 %
# Epoch [51/60], Training loss: 2.2887, Train accuracy: 9.964
# Validation loss: 2.3610, Validation accuracy: 10.0 %
# Epoch [52/60], Training loss: 2.2607, Train accuracy: 9.762
# Validation loss: 2.3212, Validation accuracy: 10.0 %
# Epoch [53/60], Training loss: 2.3030, Train accuracy: 10.002
# Validation loss: 2.3198, Validation accuracy: 10.0 %
# Epoch [54/60], Training loss: 2.2273, Train accuracy: 10.178
# Validation loss: 2.5347, Validation accuracy: 10.0 %
# Epoch [55/60], Training loss: 2.3010, Train accuracy: 9.908
# Validation loss: 2.3476, Validation accuracy: 10.0 %
# Epoch [56/60], Training loss: 2.3108, Train accuracy: 9.812
# Validation loss: 2.3569, Validation accuracy: 10.0 %
# Epoch [57/60], Training loss: 2.3799, Train accuracy: 9.888
# Validation loss: 2.3658, Validation accuracy: 10.0 %
# Epoch [58/60], Training loss: 2.2941, Train accuracy: 9.848
# Validation loss: 2.2984, Validation accuracy: 10.0 %
# Epoch [59/60], Training loss: 2.2957, Train accuracy: 10.158
# Validation loss: 2.3308, Validation accuracy: 10.0 %
# Epoch [60/60], Training loss: 2.2598, Train accuracy: 9.92
# Validation loss: 2.2654, Validation accuracy: 10.0 %
# =========== lr = 0.01 ==========
# Epoch [1/60], Training loss: 2.3080, Train accuracy: 10.678
# Validation loss: 2.2024, Validation accuracy: 11.01 %
# Epoch [2/60], Training loss: 2.2755, Train accuracy: 15.344
# Validation loss: 1.8063, Validation accuracy: 16.75 %
# Epoch [3/60], Training loss: 2.1052, Train accuracy: 17.296
# Validation loss: 1.8580, Validation accuracy: 18.24 %
# Epoch [4/60], Training loss: 2.2555, Train accuracy: 17.796
# Validation loss: 1.7426, Validation accuracy: 18.55 %
# Epoch [5/60], Training loss: 1.8971, Train accuracy: 17.814
# Validation loss: 1.7366, Validation accuracy: 18.05 %
# Epoch [6/60], Training loss: 1.8082, Train accuracy: 17.652
# Validation loss: 1.8786, Validation accuracy: 18.05 %
# Epoch [7/60], Training loss: 1.9966, Train accuracy: 17.794
# Validation loss: 1.9814, Validation accuracy: 15.87 %
# Epoch [8/60], Training loss: 2.0140, Train accuracy: 17.828
# Validation loss: 1.8258, Validation accuracy: 18.54 %
# Epoch [9/60], Training loss: 1.9915, Train accuracy: 17.906
# Validation loss: 1.7424, Validation accuracy: 18.73 %
# Epoch [10/60], Training loss: 1.9078, Train accuracy: 18.084
# Validation loss: 2.0410, Validation accuracy: 17.82 %
# Epoch [11/60], Training loss: 2.0574, Train accuracy: 17.718
# Validation loss: 1.9856, Validation accuracy: 19.08 %
# Epoch [12/60], Training loss: 1.7635, Train accuracy: 18.508
# Validation loss: 1.9433, Validation accuracy: 17.91 %
# Epoch [13/60], Training loss: 1.9832, Train accuracy: 18.566
# Validation loss: 2.0389, Validation accuracy: 18.06 %
# Epoch [14/60], Training loss: 1.9543, Train accuracy: 18.6
# Validation loss: 2.0841, Validation accuracy: 18.43 %
# Epoch [15/60], Training loss: 1.8925, Train accuracy: 18.59
# Validation loss: 1.9403, Validation accuracy: 17.73 %
# Epoch [16/60], Training loss: 2.0065, Train accuracy: 18.466
# Validation loss: 2.0041, Validation accuracy: 17.84 %
# Epoch [17/60], Training loss: 1.8712, Train accuracy: 18.5
# Validation loss: 1.9606, Validation accuracy: 17.08 %
# Epoch [18/60], Training loss: 2.1612, Train accuracy: 18.26
# Validation loss: 1.8656, Validation accuracy: 18.73 %
# Epoch [19/60], Training loss: 2.5156, Train accuracy: 18.682
# Validation loss: 2.1566, Validation accuracy: 18.45 %
# Epoch [20/60], Training loss: 1.8279, Train accuracy: 18.108
# Validation loss: 1.8671, Validation accuracy: 17.87 %
# Epoch [21/60], Training loss: 1.9631, Train accuracy: 18.33
# Validation loss: 1.6714, Validation accuracy: 18.85 %
# Epoch [22/60], Training loss: 1.8600, Train accuracy: 18.196
# Validation loss: 2.0982, Validation accuracy: 18.34 %
# Epoch [23/60], Training loss: 1.8986, Train accuracy: 18.18
# Validation loss: 1.8156, Validation accuracy: 18.21 %
# Epoch [24/60], Training loss: 1.7304, Train accuracy: 18.37
# Validation loss: 1.8170, Validation accuracy: 18.07 %
# Epoch [25/60], Training loss: 2.0228, Train accuracy: 18.458
# Validation loss: 1.9061, Validation accuracy: 17.64 %
# Epoch [26/60], Training loss: 2.2022, Train accuracy: 18.436
# Validation loss: 2.1174, Validation accuracy: 18.7 %
# Epoch [27/60], Training loss: 2.1912, Train accuracy: 17.89
# Validation loss: 1.9246, Validation accuracy: 20.09 %
# Epoch [28/60], Training loss: 1.9161, Train accuracy: 18.12
# Validation loss: 1.9152, Validation accuracy: 18.28 %
# Epoch [29/60], Training loss: 2.1816, Train accuracy: 18.518
# Validation loss: 1.9602, Validation accuracy: 18.83 %
# Epoch [30/60], Training loss: 2.2076, Train accuracy: 18.446
# Validation loss: 1.8928, Validation accuracy: 16.84 %
# Epoch [31/60], Training loss: 1.8546, Train accuracy: 18.446
# Validation loss: 1.8376, Validation accuracy: 20.04 %
# Epoch [32/60], Training loss: 1.8340, Train accuracy: 19.034
# Validation loss: 2.2349, Validation accuracy: 17.45 %
# Epoch [33/60], Training loss: 1.9232, Train accuracy: 18.576
# Validation loss: 1.8772, Validation accuracy: 19.19 %
# Epoch [34/60], Training loss: 1.9239, Train accuracy: 18.402
# Validation loss: 1.9041, Validation accuracy: 19.33 %
# Epoch [35/60], Training loss: 1.8569, Train accuracy: 18.584
# Validation loss: 1.9829, Validation accuracy: 18.82 %
# Epoch [36/60], Training loss: 2.0570, Train accuracy: 18.602
# Validation loss: 1.9248, Validation accuracy: 18.33 %
# Epoch [37/60], Training loss: 1.9787, Train accuracy: 18.606
# Validation loss: 1.8106, Validation accuracy: 18.43 %
# Epoch [38/60], Training loss: 1.7894, Train accuracy: 18.388
# Validation loss: 1.8927, Validation accuracy: 19.32 %
# Epoch [39/60], Training loss: 2.2825, Train accuracy: 18.648
# Validation loss: 2.0851, Validation accuracy: 19.11 %
# Epoch [40/60], Training loss: 2.1087, Train accuracy: 18.832
# Validation loss: 1.8538, Validation accuracy: 18.93 %
# Epoch [41/60], Training loss: 2.1837, Train accuracy: 18.744
# Validation loss: 1.9697, Validation accuracy: 18.59 %
# Epoch [42/60], Training loss: 2.0672, Train accuracy: 18.664
# Validation loss: 1.9858, Validation accuracy: 18.62 %
# Epoch [43/60], Training loss: 1.8722, Train accuracy: 18.562
# Validation loss: 1.8700, Validation accuracy: 19.93 %
# Epoch [44/60], Training loss: 1.9926, Train accuracy: 19.298
# Validation loss: 2.0656, Validation accuracy: 19.18 %
# Epoch [45/60], Training loss: 1.7417, Train accuracy: 18.934
# Validation loss: 2.3636, Validation accuracy: 20.01 %
# Epoch [46/60], Training loss: 2.1358, Train accuracy: 18.888
# Validation loss: 2.0647, Validation accuracy: 18.99 %
# Epoch [47/60], Training loss: 2.1344, Train accuracy: 18.974
# Validation loss: 1.9980, Validation accuracy: 19.54 %
# Epoch [48/60], Training loss: 2.5325, Train accuracy: 18.938
# Validation loss: 2.2320, Validation accuracy: 18.86 %
# Epoch [49/60], Training loss: 1.8368, Train accuracy: 18.988
# Validation loss: 1.9599, Validation accuracy: 19.1 %
# Epoch [50/60], Training loss: 2.2254, Train accuracy: 19.47
# Validation loss: 2.1470, Validation accuracy: 19.37 %
# Epoch [51/60], Training loss: 1.7265, Train accuracy: 19.44
# Validation loss: 1.7652, Validation accuracy: 18.17 %
# Epoch [52/60], Training loss: 1.7621, Train accuracy: 19.58
# Validation loss: 1.9232, Validation accuracy: 20.45 %
# Epoch [53/60], Training loss: 1.9645, Train accuracy: 19.972
# Validation loss: 2.1910, Validation accuracy: 20.56 %
# Epoch [54/60], Training loss: 2.1878, Train accuracy: 19.99
# Validation loss: 1.9115, Validation accuracy: 19.31 %
# Epoch [55/60], Training loss: 1.9016, Train accuracy: 19.93
# Validation loss: 2.1214, Validation accuracy: 20.21 %
# Epoch [56/60], Training loss: 1.9448, Train accuracy: 20.082
# Validation loss: 2.3309, Validation accuracy: 19.6 %
# Epoch [57/60], Training loss: 2.0832, Train accuracy: 20.016
# Validation loss: 2.0809, Validation accuracy: 19.72 %
# Epoch [58/60], Training loss: 2.6333, Train accuracy: 20.218
# Validation loss: 2.0224, Validation accuracy: 19.91 %
# Epoch [59/60], Training loss: 1.8067, Train accuracy: 19.634
# Validation loss: 2.1142, Validation accuracy: 20.18 %
# Epoch [60/60], Training loss: 1.9865, Train accuracy: 20.258
# Validation loss: 2.0047, Validation accuracy: 18.97 %
# =========== lr = 0.0001 ==========
# Epoch [1/60], Training loss: 1.2381, Train accuracy: 40.896
# Validation loss: 1.3907, Validation accuracy: 51.84 %
# Epoch [2/60], Training loss: 1.1650, Train accuracy: 59.32
# Validation loss: 0.9082, Validation accuracy: 65.38 %
# Epoch [3/60], Training loss: 1.3686, Train accuracy: 66.828
# Validation loss: 1.1930, Validation accuracy: 71.33 %
# Epoch [4/60], Training loss: 0.9701, Train accuracy: 70.954
# Validation loss: 0.9846, Validation accuracy: 74.28 %
# Epoch [5/60], Training loss: 0.5129, Train accuracy: 73.956
# Validation loss: 0.7122, Validation accuracy: 75.49 %
# Epoch [6/60], Training loss: 0.3906, Train accuracy: 76.708
# Validation loss: 0.6817, Validation accuracy: 77.49 %
# Epoch [7/60], Training loss: 0.9653, Train accuracy: 78.806
# Validation loss: 0.7058, Validation accuracy: 78.38 %
# Epoch [8/60], Training loss: 0.4180, Train accuracy: 80.574
# Validation loss: 0.8747, Validation accuracy: 80.22 %
# Epoch [9/60], Training loss: 0.4754, Train accuracy: 82.164
# Validation loss: 0.7336, Validation accuracy: 81.28 %
# Epoch [10/60], Training loss: 0.1313, Train accuracy: 83.436
# Validation loss: 0.5958, Validation accuracy: 82.61 %
# Epoch [11/60], Training loss: 0.4235, Train accuracy: 84.71
# Validation loss: 0.4532, Validation accuracy: 81.49 %
# Epoch [12/60], Training loss: 1.3167, Train accuracy: 85.496
# Validation loss: 0.5163, Validation accuracy: 81.53 %
# Epoch [13/60], Training loss: 0.7623, Train accuracy: 86.496
# Validation loss: 0.9380, Validation accuracy: 82.8 %
# Epoch [14/60], Training loss: 0.5213, Train accuracy: 87.434
# Validation loss: 0.6165, Validation accuracy: 83.3 %
# Epoch [15/60], Training loss: 0.1809, Train accuracy: 87.936
# Validation loss: 0.7731, Validation accuracy: 83.12 %
# Epoch [16/60], Training loss: 0.7104, Train accuracy: 88.732
# Validation loss: 0.7265, Validation accuracy: 83.78 %
# Epoch [17/60], Training loss: 0.3006, Train accuracy: 89.11
# Validation loss: 0.8800, Validation accuracy: 84.97 %
# Epoch [18/60], Training loss: 0.2989, Train accuracy: 90.016
# Validation loss: 0.8013, Validation accuracy: 84.36 %
# Epoch [19/60], Training loss: 0.3152, Train accuracy: 90.366
# Validation loss: 0.5796, Validation accuracy: 84.66 %
# Epoch [20/60], Training loss: 0.1078, Train accuracy: 90.738
# Validation loss: 0.4457, Validation accuracy: 85.23 %
# Epoch [21/60], Training loss: 0.4934, Train accuracy: 91.148
# Validation loss: 0.8345, Validation accuracy: 84.66 %
# Epoch [22/60], Training loss: 0.4605, Train accuracy: 91.406
# Validation loss: 0.9299, Validation accuracy: 85.0 %
# Epoch [23/60], Training loss: 0.0173, Train accuracy: 92.068
# Validation loss: 0.8264, Validation accuracy: 86.09 %
# Epoch [24/60], Training loss: 0.0547, Train accuracy: 92.208
# Validation loss: 0.6455, Validation accuracy: 85.31 %
# Epoch [25/60], Training loss: 0.0198, Train accuracy: 92.506
# Validation loss: 0.5655, Validation accuracy: 85.43 %
# Epoch [26/60], Training loss: 0.1714, Train accuracy: 92.924
# Validation loss: 1.0841, Validation accuracy: 84.87 %
# Epoch [27/60], Training loss: 0.1158, Train accuracy: 93.082
# Validation loss: 0.8464, Validation accuracy: 85.25 %
# Epoch [28/60], Training loss: 0.0890, Train accuracy: 93.41
# Validation loss: 1.4223, Validation accuracy: 85.71 %
# Epoch [29/60], Training loss: 0.3287, Train accuracy: 93.798
# Validation loss: 0.8661, Validation accuracy: 85.73 %
# Epoch [30/60], Training loss: 0.4376, Train accuracy: 93.76
# Validation loss: 0.8402, Validation accuracy: 85.7 %
# Epoch [31/60], Training loss: 0.2869, Train accuracy: 94.052
# Validation loss: 0.6749, Validation accuracy: 85.75 %
# Epoch [32/60], Training loss: 0.0625, Train accuracy: 94.34
# Validation loss: 1.2262, Validation accuracy: 85.75 %
# Epoch [33/60], Training loss: 0.3897, Train accuracy: 94.502
# Validation loss: 0.4424, Validation accuracy: 85.81 %
# Epoch [34/60], Training loss: 0.1255, Train accuracy: 94.574
# Validation loss: 0.7414, Validation accuracy: 85.72 %
# Epoch [35/60], Training loss: 0.6696, Train accuracy: 94.782
# Validation loss: 0.7426, Validation accuracy: 86.51 %
# Epoch [36/60], Training loss: 0.1232, Train accuracy: 94.904
# Validation loss: 1.1845, Validation accuracy: 86.07 %
# Epoch [37/60], Training loss: 0.0741, Train accuracy: 95.086
# Validation loss: 0.6554, Validation accuracy: 86.65 %
# Epoch [38/60], Training loss: 0.3542, Train accuracy: 95.362
# Validation loss: 0.9545, Validation accuracy: 85.77 %
# Epoch [39/60], Training loss: 0.0735, Train accuracy: 95.368
# Validation loss: 0.7621, Validation accuracy: 86.24 %
# Epoch [40/60], Training loss: 0.4446, Train accuracy: 95.594
# Validation loss: 0.8298, Validation accuracy: 85.73 %
# Epoch [41/60], Training loss: 0.0191, Train accuracy: 95.492
# Validation loss: 0.4152, Validation accuracy: 86.19 %
# Epoch [42/60], Training loss: 0.0221, Train accuracy: 95.786
# Validation loss: 0.6016, Validation accuracy: 85.75 %
# Epoch [43/60], Training loss: 0.0515, Train accuracy: 95.714
# Validation loss: 0.9698, Validation accuracy: 86.37 %
# Epoch [44/60], Training loss: 0.1710, Train accuracy: 95.79
# Validation loss: 0.7973, Validation accuracy: 86.09 %
# Epoch [45/60], Training loss: 0.2527, Train accuracy: 96.078
# Validation loss: 1.1491, Validation accuracy: 86.05 %
# Epoch [46/60], Training loss: 0.0183, Train accuracy: 96.002
# Validation loss: 1.3865, Validation accuracy: 86.17 %
# Epoch [47/60], Training loss: 0.0039, Train accuracy: 96.176
# Validation loss: 1.4051, Validation accuracy: 86.55 %
# Epoch [48/60], Training loss: 0.0056, Train accuracy: 96.192
# Validation loss: 0.9688, Validation accuracy: 86.36 %
# Epoch [49/60], Training loss: 0.0959, Train accuracy: 96.32
# Validation loss: 1.3265, Validation accuracy: 86.69 %
# Epoch [50/60], Training loss: 0.3458, Train accuracy: 96.42
# Validation loss: 1.1606, Validation accuracy: 86.82 %
# Epoch [51/60], Training loss: 0.0121, Train accuracy: 96.51
# Validation loss: 0.6641, Validation accuracy: 87.1 %
# Epoch [52/60], Training loss: 0.0077, Train accuracy: 96.6
# Validation loss: 1.2859, Validation accuracy: 87.2 %
# Epoch [53/60], Training loss: 0.1013, Train accuracy: 96.68
# Validation loss: 0.6083, Validation accuracy: 87.08 %
# Epoch [54/60], Training loss: 0.1264, Train accuracy: 96.69
# Validation loss: 1.3844, Validation accuracy: 86.26 %
# Epoch [55/60], Training loss: 0.2400, Train accuracy: 96.808
# Validation loss: 0.9826, Validation accuracy: 86.36 %
# Epoch [56/60], Training loss: 0.0115, Train accuracy: 96.814
# Validation loss: 1.3159, Validation accuracy: 86.9 %
# Epoch [57/60], Training loss: 0.0432, Train accuracy: 96.89
# Validation loss: 0.7151, Validation accuracy: 86.94 %
# Epoch [58/60], Training loss: 0.2956, Train accuracy: 96.926
# Validation loss: 0.9708, Validation accuracy: 86.53 %
# Epoch [59/60], Training loss: 0.1817, Train accuracy: 97.056
# Validation loss: 1.0875, Validation accuracy: 87.04 %
# Epoch [60/60], Training loss: 0.0014, Train accuracy: 97.012
# Validation loss: 1.0876, Validation accuracy: 86.13 %
# =========== lr = 0.001 ==========
# Epoch [1/60], Training loss: 1.8066, Train accuracy: 18.806
# Validation loss: 1.8118, Validation accuracy: 22.68 %
# Epoch [2/60], Training loss: 1.8408, Train accuracy: 26.904
# Validation loss: 1.7969, Validation accuracy: 32.59 %
# Epoch [3/60], Training loss: 2.1561, Train accuracy: 34.528
# Validation loss: 1.8592, Validation accuracy: 37.33 %
# Epoch [4/60], Training loss: 2.1828, Train accuracy: 42.224
# Validation loss: 1.5770, Validation accuracy: 48.0 %
# Epoch [5/60], Training loss: 1.2972, Train accuracy: 51.022
# Validation loss: 1.7284, Validation accuracy: 58.11 %
# Epoch [6/60], Training loss: 1.1740, Train accuracy: 58.12
# Validation loss: 1.0164, Validation accuracy: 63.01 %
# Epoch [7/60], Training loss: 0.8521, Train accuracy: 63.362
# Validation loss: 1.1724, Validation accuracy: 67.34 %
# Epoch [8/60], Training loss: 1.1725, Train accuracy: 66.66
# Validation loss: 1.0234, Validation accuracy: 69.44 %
# Epoch [9/60], Training loss: 0.6951, Train accuracy: 69.238
# Validation loss: 0.9128, Validation accuracy: 71.99 %
# Epoch [10/60], Training loss: 0.4794, Train accuracy: 71.102
# Validation loss: 0.8629, Validation accuracy: 73.29 %
# Epoch [11/60], Training loss: 0.4154, Train accuracy: 72.38
# Validation loss: 0.6376, Validation accuracy: 72.74 %
# Epoch [12/60], Training loss: 1.0593, Train accuracy: 73.946
# Validation loss: 0.7127, Validation accuracy: 74.81 %
# Epoch [13/60], Training loss: 0.8534, Train accuracy: 75.394
# Validation loss: 1.0000, Validation accuracy: 76.97 %
# Epoch [14/60], Training loss: 0.7837, Train accuracy: 76.706
# Validation loss: 0.7054, Validation accuracy: 77.38 %
# Epoch [15/60], Training loss: 0.9094, Train accuracy: 77.702
# Validation loss: 1.1129, Validation accuracy: 78.87 %
# Epoch [16/60], Training loss: 1.0529, Train accuracy: 78.444
# Validation loss: 0.9762, Validation accuracy: 77.95 %
# Epoch [17/60], Training loss: 0.3320, Train accuracy: 79.562
# Validation loss: 0.7387, Validation accuracy: 80.98 %
# Epoch [18/60], Training loss: 0.4673, Train accuracy: 80.37
# Validation loss: 0.9937, Validation accuracy: 80.4 %
# Epoch [19/60], Training loss: 0.4661, Train accuracy: 81.03
# Validation loss: 1.2036, Validation accuracy: 80.12 %
# Epoch [20/60], Training loss: 0.3130, Train accuracy: 81.56
# Validation loss: 0.7836, Validation accuracy: 80.51 %
# Epoch [21/60], Training loss: 0.4834, Train accuracy: 82.038
# Validation loss: 0.7443, Validation accuracy: 81.11 %
# Epoch [22/60], Training loss: 0.5437, Train accuracy: 82.486
# Validation loss: 0.8954, Validation accuracy: 82.26 %
# Epoch [23/60], Training loss: 0.1841, Train accuracy: 82.92
# Validation loss: 0.9414, Validation accuracy: 82.11 %
# Epoch [24/60], Training loss: 0.3985, Train accuracy: 83.324
# Validation loss: 0.7106, Validation accuracy: 82.61 %
# Epoch [25/60], Training loss: 0.7462, Train accuracy: 83.962
# Validation loss: 0.9852, Validation accuracy: 82.79 %
# Epoch [26/60], Training loss: 0.4116, Train accuracy: 84.258
# Validation loss: 0.6579, Validation accuracy: 81.52 %
# Epoch [27/60], Training loss: 0.3075, Train accuracy: 84.672
# Validation loss: 0.8332, Validation accuracy: 82.23 %
# Epoch [28/60], Training loss: 0.9547, Train accuracy: 84.632
# Validation loss: 0.9641, Validation accuracy: 82.07 %
# Epoch [29/60], Training loss: 0.2124, Train accuracy: 84.906
# Validation loss: 0.9394, Validation accuracy: 81.97 %
# Epoch [30/60], Training loss: 1.0937, Train accuracy: 85.066
# Validation loss: 0.8260, Validation accuracy: 81.89 %
# Epoch [31/60], Training loss: 0.3820, Train accuracy: 85.322
# Validation loss: 0.8855, Validation accuracy: 82.72 %
# Epoch [32/60], Training loss: 0.4272, Train accuracy: 85.812
# Validation loss: 0.8582, Validation accuracy: 83.55 %
# Epoch [33/60], Training loss: 0.3764, Train accuracy: 85.958
# Validation loss: 0.6424, Validation accuracy: 83.41 %
# Epoch [34/60], Training loss: 0.2743, Train accuracy: 85.72
# Validation loss: 0.5190, Validation accuracy: 83.26 %
# Epoch [35/60], Training loss: 0.7925, Train accuracy: 86.164
# Validation loss: 0.5689, Validation accuracy: 82.18 %
# Epoch [36/60], Training loss: 0.1984, Train accuracy: 86.316
# Validation loss: 0.7585, Validation accuracy: 84.03 %
# Epoch [37/60], Training loss: 0.3014, Train accuracy: 86.61
# Validation loss: 0.8137, Validation accuracy: 83.79 %
# Epoch [38/60], Training loss: 0.4948, Train accuracy: 86.502
# Validation loss: 0.5151, Validation accuracy: 83.2 %
# Epoch [39/60], Training loss: 0.7066, Train accuracy: 86.922
# Validation loss: 0.5178, Validation accuracy: 83.05 %
# Epoch [40/60], Training loss: 0.5185, Train accuracy: 87.002
# Validation loss: 0.8829, Validation accuracy: 83.9 %
# Epoch [41/60], Training loss: 0.8189, Train accuracy: 87.126
# Validation loss: 0.9899, Validation accuracy: 84.4 %
# Epoch [42/60], Training loss: 0.4539, Train accuracy: 87.148
# Validation loss: 0.4493, Validation accuracy: 84.03 %
# Epoch [43/60], Training loss: 0.6699, Train accuracy: 87.42
# Validation loss: 0.9625, Validation accuracy: 84.08 %
# Epoch [44/60], Training loss: 0.1251, Train accuracy: 87.352
# Validation loss: 0.6228, Validation accuracy: 84.13 %
# Epoch [45/60], Training loss: 0.4471, Train accuracy: 87.458
# Validation loss: 0.9909, Validation accuracy: 83.47 %
# Epoch [46/60], Training loss: 0.4866, Train accuracy: 87.532
# Validation loss: 0.7038, Validation accuracy: 84.64 %
# Epoch [47/60], Training loss: 0.2526, Train accuracy: 87.586
# Validation loss: 0.8529, Validation accuracy: 84.29 %
# Epoch [48/60], Training loss: 0.2935, Train accuracy: 87.79
# Validation loss: 0.9733, Validation accuracy: 83.03 %
# Epoch [49/60], Training loss: 0.4005, Train accuracy: 88.062
# Validation loss: 1.1224, Validation accuracy: 84.56 %
# Epoch [50/60], Training loss: 0.1623, Train accuracy: 87.976
# Validation loss: 0.6768, Validation accuracy: 84.36 %
# Epoch [51/60], Training loss: 0.1741, Train accuracy: 88.048
# Validation loss: 0.6216, Validation accuracy: 85.45 %
# Epoch [52/60], Training loss: 0.5377, Train accuracy: 88.032
# Validation loss: 0.6043, Validation accuracy: 84.38 %
# Epoch [53/60], Training loss: 0.3734, Train accuracy: 88.196
# Validation loss: 0.7854, Validation accuracy: 84.21 %
# Epoch [54/60], Training loss: 0.1740, Train accuracy: 88.256
# Validation loss: 0.8265, Validation accuracy: 84.9 %
# Epoch [55/60], Training loss: 0.6477, Train accuracy: 88.622
# Validation loss: 0.6997, Validation accuracy: 84.21 %
# Epoch [56/60], Training loss: 0.2642, Train accuracy: 88.43
# Validation loss: 0.4584, Validation accuracy: 85.42 %
# Epoch [57/60], Training loss: 0.2094, Train accuracy: 88.41
# Validation loss: 0.8937, Validation accuracy: 84.32 %
# Epoch [58/60], Training loss: 0.3259, Train accuracy: 88.582
# Validation loss: 1.1215, Validation accuracy: 84.65 %
# Epoch [59/60], Training loss: 0.2460, Train accuracy: 88.512
# Validation loss: 1.2200, Validation accuracy: 84.97 %
# Epoch [60/60], Training loss: 0.3457, Train accuracy: 88.79
# Validation loss: 0.8936, Validation accuracy: 83.85 %

# %%
# Accuracy comparision among the learning rates
plot_acc_lr(epochs,lr_list,vgg16_train_acc,vgg16_val_acc)

# %% [markdown]
# #### 1.7 Get the best model and examine cnn layers

# %%
# Define model parameters
lr = 0.01
epochs = 53
model = VGG16(10).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum = 0.9)
save_path = 'gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16/SGD'

# %%
# Train the model
vgg16_train_acc, vgg16_train_loss, vgg16_val_acc, vgg16_val_loss = train_validate_model(train_dataloader_2,val_dataloader_1,model,epochs,optimizer, save_path)
# Out:
# Epoch [1/53], Training loss: 1.6854, Train accuracy: 33.232
# Validation loss: 1.6307, Validation accuracy: 43.43 %
# Epoch [2/53], Training loss: 0.7708, Train accuracy: 51.274
# Validation loss: 1.4188, Validation accuracy: 58.88 %
# Epoch [3/53], Training loss: 1.1852, Train accuracy: 62.13
# Validation loss: 1.2936, Validation accuracy: 66.3 %
# Epoch [4/53], Training loss: 1.6640, Train accuracy: 67.2
# Validation loss: 1.1264, Validation accuracy: 71.45 %
# Epoch [5/53], Training loss: 0.7518, Train accuracy: 71.25
# Validation loss: 0.7398, Validation accuracy: 73.94 %
# Epoch [6/53], Training loss: 1.8373, Train accuracy: 74.038
# Validation loss: 0.7831, Validation accuracy: 75.21 %
# Epoch [7/53], Training loss: 0.9151, Train accuracy: 76.376
# Validation loss: 1.0581, Validation accuracy: 78.64 %
# Epoch [8/53], Training loss: 1.1869, Train accuracy: 78.802
# Validation loss: 1.2297, Validation accuracy: 78.97 %
# Epoch [9/53], Training loss: 0.4784, Train accuracy: 80.37
# Validation loss: 0.9095, Validation accuracy: 79.63 %
# Epoch [10/53], Training loss: 0.6227, Train accuracy: 81.98
# Validation loss: 0.5874, Validation accuracy: 81.65 %
# Epoch [11/53], Training loss: 0.6172, Train accuracy: 83.276
# Validation loss: 0.6902, Validation accuracy: 81.71 %
# Epoch [12/53], Training loss: 0.3949, Train accuracy: 84.584
# Validation loss: 0.5344, Validation accuracy: 81.78 %
# Epoch [13/53], Training loss: 0.2943, Train accuracy: 85.532
# Validation loss: 0.6806, Validation accuracy: 82.38 %
# Epoch [14/53], Training loss: 0.3398, Train accuracy: 86.384
# Validation loss: 0.8278, Validation accuracy: 84.26 %
# Epoch [15/53], Training loss: 0.2677, Train accuracy: 87.148
# Validation loss: 0.6105, Validation accuracy: 83.65 %
# Epoch [16/53], Training loss: 0.2171, Train accuracy: 88.09
# Validation loss: 0.5296, Validation accuracy: 85.48 %
# Epoch [17/53], Training loss: 0.3985, Train accuracy: 88.746
# Validation loss: 0.6071, Validation accuracy: 84.68 %
# Epoch [18/53], Training loss: 0.4136, Train accuracy: 89.304
# Validation loss: 0.4272, Validation accuracy: 84.62 %
# Epoch [19/53], Training loss: 0.3185, Train accuracy: 90.19
# Validation loss: 0.7901, Validation accuracy: 85.62 %
# Epoch [20/53], Training loss: 0.3634, Train accuracy: 90.702
# Validation loss: 0.6327, Validation accuracy: 85.91 %
# Epoch [21/53], Training loss: 0.4524, Train accuracy: 91.216
# Validation loss: 0.8291, Validation accuracy: 86.16 %
# Epoch [22/53], Training loss: 0.1333, Train accuracy: 91.734
# Validation loss: 0.8338, Validation accuracy: 84.46 %
# Epoch [23/53], Training loss: 0.3063, Train accuracy: 92.14
# Validation loss: 0.5671, Validation accuracy: 85.37 %
# Epoch [24/53], Training loss: 0.0542, Train accuracy: 92.632
# Validation loss: 0.1720, Validation accuracy: 85.92 %
# Epoch [25/53], Training loss: 0.1855, Train accuracy: 93.046
# Validation loss: 0.3311, Validation accuracy: 86.66 %
# Epoch [26/53], Training loss: 0.2353, Train accuracy: 93.542
# Validation loss: 0.3173, Validation accuracy: 86.85 %
# Epoch [27/53], Training loss: 0.1473, Train accuracy: 93.79
# Validation loss: 0.3421, Validation accuracy: 86.23 %
# Epoch [28/53], Training loss: 0.0717, Train accuracy: 94.124
# Validation loss: 0.6909, Validation accuracy: 86.28 %
# Epoch [29/53], Training loss: 0.1398, Train accuracy: 94.342
# Validation loss: 0.4561, Validation accuracy: 86.27 %
# Epoch [30/53], Training loss: 0.0278, Train accuracy: 94.608
# Validation loss: 0.5566, Validation accuracy: 87.31 %
# Epoch [31/53], Training loss: 0.0380, Train accuracy: 95.116
# Validation loss: 0.6295, Validation accuracy: 86.79 %
# Epoch [32/53], Training loss: 0.1032, Train accuracy: 95.104
# Validation loss: 0.6257, Validation accuracy: 86.81 %
# Epoch [33/53], Training loss: 0.2210, Train accuracy: 95.314
# Validation loss: 0.6992, Validation accuracy: 86.51 %
# Epoch [34/53], Training loss: 0.0631, Train accuracy: 95.508
# Validation loss: 0.5006, Validation accuracy: 86.63 %
# Epoch [35/53], Training loss: 0.1004, Train accuracy: 95.894
# Validation loss: 0.5153, Validation accuracy: 87.0 %
# Epoch [36/53], Training loss: 0.0387, Train accuracy: 95.806
# Validation loss: 0.3556, Validation accuracy: 86.99 %
# Epoch [37/53], Training loss: 0.3799, Train accuracy: 96.268
# Validation loss: 0.6712, Validation accuracy: 87.35 %
# Epoch [38/53], Training loss: 0.4293, Train accuracy: 96.238
# Validation loss: 0.7773, Validation accuracy: 86.64 %
# Epoch [39/53], Training loss: 0.0259, Train accuracy: 96.458
# Validation loss: 0.6246, Validation accuracy: 87.48 %
# Epoch [40/53], Training loss: 0.3464, Train accuracy: 96.586
# Validation loss: 0.8031, Validation accuracy: 87.08 %
# Epoch [41/53], Training loss: 0.0381, Train accuracy: 96.884
# Validation loss: 0.5723, Validation accuracy: 87.99 %
# Epoch [42/53], Training loss: 0.3642, Train accuracy: 97.062
# Validation loss: 0.6509, Validation accuracy: 87.61 %
# Epoch [43/53], Training loss: 0.3326, Train accuracy: 97.146
# Validation loss: 0.2714, Validation accuracy: 87.52 %
# Epoch [44/53], Training loss: 0.0412, Train accuracy: 97.15
# Validation loss: 0.5126, Validation accuracy: 88.16 %
# Epoch [45/53], Training loss: 0.2725, Train accuracy: 97.406
# Validation loss: 1.0070, Validation accuracy: 87.47 %
# Epoch [46/53], Training loss: 0.0584, Train accuracy: 97.318
# Validation loss: 1.0102, Validation accuracy: 87.8 %
# Epoch [47/53], Training loss: 0.0949, Train accuracy: 97.566
# Validation loss: 0.5207, Validation accuracy: 87.91 %
# Epoch [48/53], Training loss: 0.0172, Train accuracy: 97.648
# Validation loss: 0.5691, Validation accuracy: 87.58 %
# Epoch [49/53], Training loss: 0.0039, Train accuracy: 97.758
# Validation loss: 0.8508, Validation accuracy: 87.69 %
# Epoch [50/53], Training loss: 0.0134, Train accuracy: 97.788
# Validation loss: 0.5681, Validation accuracy: 87.36 %
# Epoch [51/53], Training loss: 0.0758, Train accuracy: 97.828
# Validation loss: 0.5491, Validation accuracy: 87.62 %
# Epoch [52/53], Training loss: 0.0082, Train accuracy: 97.976
# Validation loss: 0.6874, Validation accuracy: 87.88 %
# Epoch [53/53], Training loss: 0.1730, Train accuracy: 98.098
# Validation loss: 0.7272, Validation accuracy: 87.56 %

# %%
# Load model
model = VGG16(10).to(device)
model.load_state_dict(torch.load('gdrive/MyDrive/Portfolio/CIFAR-10 image classification/VGG16/SGD/53epoch.pt'))
print(model)
# Out:
# VGG16(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer4): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer5): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer6): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer7): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer8): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer9): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer10): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer11): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer12): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (layer13): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=512, out_features=4096, bias=True)
#     (2): ReLU()
#   )
#   (fc1): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=4096, out_features=4096, bias=True)
#     (2): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
model_children = list(model.children())
model_children[0]
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
# )

# %%
# Extract convolution layers
model_weights =[]
conv_layers = []
model_children = list(model.children())
counter = 0

for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            if type(model_children[i][j]) == nn.Conv2d:
                counter+=1
                model_weights.append(model_children[i][j].weight)
                conv_layers.append(model_children[i][j])

print(f"Total convolution layers: {counter}")
print(conv_layers)
# Out:
# Total convolution layers: 13
# [Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)), Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))]

# %%
# Pick an image to view
image = trainset_2.data[14]
plt.imshow(image)
plt.title("Original image")
image = transform_train_2(image)
image = image.to(device)

# %%
# Generate feature maps
outputs = []
names = []
for layer in conv_layers[0:]:
    image = layer(image)
    outputs.append(image)
    names.append(str(layer))

# Convert 3d to 2d, sum same element of every channel
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())

# Visualize feature maps
fig = plt.figure(figsize=(20, 6))
fig.subplots_adjust(hspace=0.01, wspace=0.2)
count = 0
for i in range(len(processed)):
    count = count + 1
    a = fig.add_subplot(2, 7, i+1)
    imgplot = plt.imshow(processed[i],cmap="gray")
    a.axis("off")
    a.set_title(f"conv2d layer {count}")

# %%
# Visualize the first conv layer filters
plt.figure(figsize=(7, 7))
count = 0
for i, filter in enumerate(model_weights[0]):
    count = count + 1
    plt.subplot(8, 8, i+1) # (3, 3) because in 1st conv2d, we have 3x3 filters and total of 64 output channels
    plt.imshow(filter[0, :, :].detach().cpu(), cmap='gray')
    plt.axis('off')
plt.show()

# %%
# Use the same image to analyze
image = trainset_2.data[14]
image = transform_train_2(image)
image = image.to(device)
# Pass the image through all the layers
results = [conv_layers[0](image)]
for i in range(1, len(conv_layers)):
    # Pass the result from the last layer to the next layer
    results.append(conv_layers[i](results[-1]))
# Make a copy of the 'results'
outputs = results

# Visualize 64 features of conv layer 1
plt.figure(figsize=(10, 10))
layer_viz = outputs[0]
layer_viz = layer_viz.data
print(layer_viz.size())
for i, filter in enumerate(layer_viz):
    plt.subplot(8, 8, i + 1)
    plt.imshow(filter.cpu(), cmap='gray')
    plt.axis("off")
print(f"Layer 1 feature maps...")
plt.show()
# Out:
# torch.Size([64, 32, 32])
# Layer 1 feature maps...
